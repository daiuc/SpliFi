# %% [raw]
# ---
# title: "GTEx unproductive splicing reads"
# date: 2024-1-11
# author: "Chao Dai"
# code-fold: true
# execute:
#   warning: false
#   message: false
#   echo: false
#   include: false
# categories:
#   - "GTEx"
# jupyter:
#     language: r
# ---

# %%
# use R to change path to ~/cdai/SpliFi/analysis if current working path is not

setwd("~/cdai/SpliFi/analysis")

# %%
suppressMessages(library(tidyverse))
suppressMessages(library(glue))
suppressMessages(library(data.table))
suppressMessages(library(cowplot))

# %%
theme_set(theme_cowplot())

# %%
library(furrr)
plan(multisession, workers = 6)
# Out:
# Loading required package: future

# %%
options(repr.plot.width = 8, repr.plot.height=10, repr.plot.res = 180)

# %%
tissues  <- dir('../code/results/pheno/noisy/GTEx')
tissues  <- tissues[-which(tissues %in% c("Bladder", "Kidney-Medulla"))]
length(tissues)
tissues
# Out:
# [1] 49
#  [1] "Adipose-Subcutaneous"
#  [2] "Adipose-Visceral_Omentum_"
#  [3] "AdrenalGland"
#  [4] "Artery-Aorta"
#  [5] "Artery-Coronary"
#  [6] "Artery-Tibial"
#  [7] "Brain-Amygdala"
#  [8] "Brain-Anteriorcingulatecortex_BA24_"
#  [9] "Brain-Caudate_basalganglia_"
# [10] "Brain-CerebellarHemisphere"
# [11] "Brain-Cerebellum"
# [12] "Brain-Cortex"
# [13] "Brain-FrontalCortex_BA9_"
# [14] "Brain-Hippocampus"
# [15] "Brain-Hypothalamus"
# [16] "Brain-Nucleusaccumbens_basalganglia_"
# [17] "Brain-Putamen_basalganglia_"
# [18] "Brain-Spinalcord_cervicalc-1_"
# [19] "Brain-Substantianigra"
# [20] "Breast-MammaryTissue"
# [21] "Cells-Culturedfibroblasts"
# [22] "Cells-EBV-transformedlymphocytes"
# [23] "Colon-Sigmoid"
# [24] "Colon-Transverse"
# [25] "Esophagus-GastroesophagealJunction"
# [26] "Esophagus-Mucosa"
# [27] "Esophagus-Muscularis"
# [28] "Heart-AtrialAppendage"
# [29] "Heart-LeftVentricle"
# [30] "Kidney-Cortex"
# [31] "Liver"
# [32] "Lung"
# [33] "MinorSalivaryGland"
# [34] "Muscle-Skeletal"
# [35] "Nerve-Tibial"
# [36] "Ovary"
# [37] "Pancreas"
# [38] "Pituitary"
# [39] "Prostate"
# [40] "Skin-NotSunExposed_Suprapubic_"
# [41] "Skin-SunExposed_Lowerleg_"
# [42] "SmallIntestine-TerminalIleum"
# [43] "Spleen"
# [44] "Stomach"
# [45] "Testis"
# [46] "Thyroid"
# [47] "Uterus"
# [48] "Vagina"
# [49] "WholeBlood"

# %% [markdown]
# Processed these GTEx tissues:

# %%
#| include: true
print(glue("Number of tissues: {length(tissues)}"))
print(glue("Tissues: {str_wrap(paste(tissues, collapse = ', '), 120)}"))
# Out:
# Number of tissues: 49
# Tissues: Adipose-Subcutaneous, Adipose-Visceral_Omentum_, AdrenalGland, Artery-Aorta, Artery-Coronary, Artery-Tibial,
# Brain-Amygdala, Brain-Anteriorcingulatecortex_BA24_, Brain-Caudate_basalganglia_, Brain-CerebellarHemisphere,
# Brain-Cerebellum, Brain-Cortex, Brain-FrontalCortex_BA9_, Brain-Hippocampus, Brain-Hypothalamus,
# Brain-Nucleusaccumbens_basalganglia_, Brain-Putamen_basalganglia_, Brain-Spinalcord_cervicalc-1_, Brain-Substantianigra,
# Breast-MammaryTissue, Cells-Culturedfibroblasts, Cells-EBV-transformedlymphocytes, Colon-Sigmoid, Colon-Transverse,
# Esophagus-GastroesophagealJunction, Esophagus-Mucosa, Esophagus-Muscularis, Heart-AtrialAppendage, Heart-LeftVentricle,
# Kidney-Cortex, Liver, Lung, MinorSalivaryGland, Muscle-Skeletal, Nerve-Tibial, Ovary, Pancreas, Pituitary, Prostate,
# Skin-NotSunExposed_Suprapubic_, Skin-SunExposed_Lowerleg_, SmallIntestine-TerminalIleum, Spleen, Stomach, Testis,
# Thyroid, Uterus, Vagina, WholeBlood

# %%
computeUnprodRatio <- function(tissue_rds) {

    introns <- readRDS(tissue_rds)
    datacols <- names(introns)[5:ncol(introns)]
    # remove clu_type == N, clusters with only unproductive introns
    introns  <- introns[str_detect(clu_type, 'PR')]
    # total reads (by sample)
    totals <- colSums(introns[, ..datacols])
    # unproudctive reads (by sample)
    unprod <- introns[intron_type == 'UP', ..datacols] %>% colSums
    # unproductive reads / total reads
    if (all(names(totals) == names(unprod))) {
        unprod_ratio <- round(unprod / totals, 5)
    } else {
        stop('samples of totals and unprod are not the same')
    }

    return(unprod_ratio)

}

# %%
#tissues
tissues_rds <- glue('/project2/yangili1/cdai/SpliFi/data/ExtractFractions/GTEx/{tissues}.numerators_constcounts.noise_by_intron.rds')
names(tissues_rds) <- tissus
print(glue("{seq_along(tissues_rds)}:{tissues_rds}"))
# Out:
# 1:/project2/yangili1/cdai/SpliFi/data/ExtractFractions/GTEx/Adipose-Subcutaneous.numerators_constcounts.noise_by_intron.rds
# 2:/project2/yangili1/cdai/SpliFi/data/ExtractFractions/GTEx/Adipose-Visceral_Omentum_.numerators_constcounts.noise_by_intron.rds
# 3:/project2/yangili1/cdai/SpliFi/data/ExtractFractions/GTEx/AdrenalGland.numerators_constcounts.noise_by_intron.rds
# 4:/project2/yangili1/cdai/SpliFi/data/ExtractFractions/GTEx/Artery-Aorta.numerators_constcounts.noise_by_intron.rds
# 5:/project2/yangili1/cdai/SpliFi/data/ExtractFractions/GTEx/Artery-Coronary.numerators_constcounts.noise_by_intron.rds
# 6:/project2/yangili1/cdai/SpliFi/data/ExtractFractions/GTEx/Artery-Tibial.numerators_constcounts.noise_by_intron.rds
# 7:/project2/yangili1/cdai/SpliFi/data/ExtractFractions/GTEx/Brain-Amygdala.numerators_constcounts.noise_by_intron.rds
# 8:/project2/yangili1/cdai/SpliFi/data/ExtractFractions/GTEx/Brain-Anteriorcingulatecortex_BA24_.numerators_constcounts.noise_by_intron.rds
# 9:/project2/yangili1/cdai/SpliFi/data/ExtractFractions/GTEx/Brain-Caudate_basalganglia_.numerators_constcounts.noise_by_intron.rds
# 10:/project2/yangili1/cdai/SpliFi/data/ExtractFractions/GTEx/Brain-CerebellarHemisphere.numerators_constcounts.noise_by_intron.rds
# 11:/project2/yangili1/cdai/SpliFi/data/ExtractFractions/GTEx/Brain-Cerebellum.numerators_constcounts.noise_by_intron.rds
# 12:/project2/yangili1/cdai/SpliFi/data/ExtractFractions/GTEx/Brain-Cortex.numerators_constcounts.noise_by_intron.rds
# 13:/project2/yangili1/cdai/SpliFi/data/ExtractFractions/GTEx/Brain-FrontalCortex_BA9_.numerators_constcounts.noise_by_intron.rds
# 14:/project2/yangili1/cdai/SpliFi/data/ExtractFractions/GTEx/Brain-Hippocampus.numerators_constcounts.noise_by_intron.rds
# 15:/project2/yangili1/cdai/SpliFi/data/ExtractFractions/GTEx/Brain-Hypothalamus.numerators_constcounts.noise_by_intron.rds
# 16:/project2/yangili1/cdai/SpliFi/data/ExtractFractions/GTEx/Brain-Nucleusaccumbens_basalganglia_.numerators_constcounts.noise_by_intron.rds
# 17:/project2/yangili1/cdai/SpliFi/data/ExtractFractions/GTEx/Brain-Putamen_basalganglia_.numerators_constcounts.noise_by_intron.rds
# 18:/project2/yangili1/cdai/SpliFi/data/ExtractFractions/GTEx/Brain-Spinalcord_cervicalc-1_.numerators_constcounts.noise_by_intron.rds
# 19:/project2/yangili1/cdai/SpliFi/data/ExtractFractions/GTEx/Brain-Substantianigra.numerators_constcounts.noise_by_intron.rds
# 20:/project2/yangili1/cdai/SpliFi/data/ExtractFractions/GTEx/Breast-MammaryTissue.numerators_constcounts.noise_by_intron.rds
# 21:/project2/yangili1/cdai/SpliFi/data/ExtractFractions/GTEx/Cells-Culturedfibroblasts.numerators_constcounts.noise_by_intron.rds
# 22:/project2/yangili1/cdai/SpliFi/data/ExtractFractions/GTEx/Cells-EBV-transformedlymphocytes.numerators_constcounts.noise_by_intron.rds
# 23:/project2/yangili1/cdai/SpliFi/data/ExtractFractions/GTEx/Colon-Sigmoid.numerators_constcounts.noise_by_intron.rds
# 24:/project2/yangili1/cdai/SpliFi/data/ExtractFractions/GTEx/Colon-Transverse.numerators_constcounts.noise_by_intron.rds
# 25:/project2/yangili1/cdai/SpliFi/data/ExtractFractions/GTEx/Esophagus-GastroesophagealJunction.numerators_constcounts.noise_by_intron.rds
# 26:/project2/yangili1/cdai/SpliFi/data/ExtractFractions/GTEx/Esophagus-Mucosa.numerators_constcounts.noise_by_intron.rds
# 27:/project2/yangili1/cdai/SpliFi/data/ExtractFractions/GTEx/Esophagus-Muscularis.numerators_constcounts.noise_by_intron.rds
# 28:/project2/yangili1/cdai/SpliFi/data/ExtractFractions/GTEx/Heart-AtrialAppendage.numerators_constcounts.noise_by_intron.rds
# 29:/project2/yangili1/cdai/SpliFi/data/ExtractFractions/GTEx/Heart-LeftVentricle.numerators_constcounts.noise_by_intron.rds
# 30:/project2/yangili1/cdai/SpliFi/data/ExtractFractions/GTEx/Kidney-Cortex.numerators_constcounts.noise_by_intron.rds
# 31:/project2/yangili1/cdai/SpliFi/data/ExtractFractions/GTEx/Liver.numerators_constcounts.noise_by_intron.rds
# 32:/project2/yangili1/cdai/SpliFi/data/ExtractFractions/GTEx/Lung.numerators_constcounts.noise_by_intron.rds
# 33:/project2/yangili1/cdai/SpliFi/data/ExtractFractions/GTEx/MinorSalivaryGland.numerators_constcounts.noise_by_intron.rds
# 34:/project2/yangili1/cdai/SpliFi/data/ExtractFractions/GTEx/Muscle-Skeletal.numerators_constcounts.noise_by_intron.rds
# 35:/project2/yangili1/cdai/SpliFi/data/ExtractFractions/GTEx/Nerve-Tibial.numerators_constcounts.noise_by_intron.rds
# 36:/project2/yangili1/cdai/SpliFi/data/ExtractFractions/GTEx/Ovary.numerators_constcounts.noise_by_intron.rds
# 37:/project2/yangili1/cdai/SpliFi/data/ExtractFractions/GTEx/Pancreas.numerators_constcounts.noise_by_intron.rds
# 38:/project2/yangili1/cdai/SpliFi/data/ExtractFractions/GTEx/Pituitary.numerators_constcounts.noise_by_intron.rds
# 39:/project2/yangili1/cdai/SpliFi/data/ExtractFractions/GTEx/Prostate.numerators_constcounts.noise_by_intron.rds
# 40:/project2/yangili1/cdai/SpliFi/data/ExtractFractions/GTEx/Skin-NotSunExposed_Suprapubic_.numerators_constcounts.noise_by_intron.rds
# 41:/project2/yangili1/cdai/SpliFi/data/ExtractFractions/GTEx/Skin-SunExposed_Lowerleg_.numerators_constcounts.noise_by_intron.rds
# 42:/project2/yangili1/cdai/SpliFi/data/ExtractFractions/GTEx/SmallIntestine-TerminalIleum.numerators_constcounts.noise_by_intron.rds
# 43:/project2/yangili1/cdai/SpliFi/data/ExtractFractions/GTEx/Spleen.numerators_constcounts.noise_by_intron.rds
# 44:/project2/yangili1/cdai/SpliFi/data/ExtractFractions/GTEx/Stomach.numerators_constcounts.noise_by_intron.rds
# 45:/project2/yangili1/cdai/SpliFi/data/ExtractFractions/GTEx/Testis.numerators_constcounts.noise_by_intron.rds
# 46:/project2/yangili1/cdai/SpliFi/data/ExtractFractions/GTEx/Thyroid.numerators_constcounts.noise_by_intron.rds
# 47:/project2/yangili1/cdai/SpliFi/data/ExtractFractions/GTEx/Uterus.numerators_constcounts.noise_by_intron.rds
# 48:/project2/yangili1/cdai/SpliFi/data/ExtractFractions/GTEx/Vagina.numerators_constcounts.noise_by_intron.rds
# 49:/project2/yangili1/cdai/SpliFi/data/ExtractFractions/GTEx/WholeBlood.numerators_constcounts.noise_by_intron.rds

# %%
ratios <- map(tissues_rds, computeUnprodRatio)
# Out:
#  ■■                                 2% |  ETA:  6m
#
#  ■■                                 4% |  ETA:  5m
#
#  ■■■                                6% |  ETA:  3m
#
#  ■■■                                8% |  ETA:  3m
#
#  ■■■■                              10% |  ETA:  3m
#
#  ■■■■■                             12% |  ETA:  3m
#
#  ■■■■■                             14% |  ETA:  2m
#
#  ■■■■■■■                           18% |  ETA:  2m
#
#  ■■■■■■■■                          22% |  ETA:  2m
#
#  ■■■■■■■■                          24% |  ETA:  2m
#
#  ■■■■■■■■■■                        29% |  ETA:  2m
#
#  ■■■■■■■■■■                        31% |  ETA:  2m
#
#  ■■■■■■■■■■■                       35% |  ETA:  2m
#
#  ■■■■■■■■■■■■■                     39% |  ETA:  1m
#
#  ■■■■■■■■■■■■■                     41% |  ETA:  1m
#
#  ■■■■■■■■■■■■■■                    43% |  ETA:  1m
#
#  ■■■■■■■■■■■■■■                    45% |  ETA:  1m
#
#  ■■■■■■■■■■■■■■■                   47% |  ETA:  1m
#
#  ■■■■■■■■■■■■■■■■                  49% |  ETA:  1m
#
#  ■■■■■■■■■■■■■■■■                  51% |  ETA:  1m
#
#  ■■■■■■■■■■■■■■■■■                 53% |  ETA:  1m
#
#  ■■■■■■■■■■■■■■■■■■                55% |  ETA:  1m
#
#  ■■■■■■■■■■■■■■■■■■                57% |  ETA:  1m
#
#  ■■■■■■■■■■■■■■■■■■■               59% |  ETA:  1m
#
#  ■■■■■■■■■■■■■■■■■■■■              63% |  ETA:  1m
#
#  ■■■■■■■■■■■■■■■■■■■■■             65% |  ETA: 49s
#
#  ■■■■■■■■■■■■■■■■■■■■■             67% |  ETA: 45s
#
#  ■■■■■■■■■■■■■■■■■■■■■■            69% |  ETA: 44s
#
#  ■■■■■■■■■■■■■■■■■■■■■■            71% |  ETA: 42s
#
#  ■■■■■■■■■■■■■■■■■■■■■■■           73% |  ETA: 38s
#
#  ■■■■■■■■■■■■■■■■■■■■■■■■          78% |  ETA: 32s
#
#  ■■■■■■■■■■■■■■■■■■■■■■■■■         80% |  ETA: 29s
#
#  ■■■■■■■■■■■■■■■■■■■■■■■■■         82% |  ETA: 26s
#
#  ■■■■■■■■■■■■■■■■■■■■■■■■■■        84% |  ETA: 24s
#
#  ■■■■■■■■■■■■■■■■■■■■■■■■■■■       86% |  ETA: 21s
#
#  ■■■■■■■■■■■■■■■■■■■■■■■■■■■■      90% |  ETA: 15s
#
#  ■■■■■■■■■■■■■■■■■■■■■■■■■■■■■     92% |  ETA: 12s
#
#  ■■■■■■■■■■■■■■■■■■■■■■■■■■■■■     94% |  ETA:  9s
#
#  ■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■    96% |  ETA:  6s

# %%
ratios <- imap_dfr(
    ratios,
    \(x, y) enframe(x, "sample", "unprodRatio") %>% add_column(tissue = y)
)

# %%
ratios  <- as.data.table(ratios) %>%
    .[, .(sample, unprodRatio, nsample = uniqueN(sample)), by = tissue]

# %%
ratios %>% head
# Out:
#   tissue               sample     unprodRatio nsample
# 1 Adipose-Subcutaneous GTEX-1117F 0.00652     663
# 2 Adipose-Subcutaneous GTEX-111CU 0.00441     663
# 3 Adipose-Subcutaneous GTEX-111FC 0.00527     663
# 4 Adipose-Subcutaneous GTEX-111VG 0.00511     663
# 5 Adipose-Subcutaneous GTEX-111YS 0.00552     663
# 6 Adipose-Subcutaneous GTEX-1122O 0.00528     663

# %%
ratios[, .(median_prod_ratio = median(unprodRatio)), by = tissue][order(-median_prod_ratio)]
# Out:
#    tissue                               median_prod_ratio
# 1  Testis                               0.009140
# 2  Brain-Cerebellum                     0.007230
# 3  Brain-CerebellarHemisphere           0.006740
# 4  Brain-Spinalcord_cervicalc-1_        0.006150
# 5  Thyroid                              0.005650
# 6  Prostate                             0.005630
# 7  Nerve-Tibial                         0.005360
# 8  Spleen                               0.005230
# 9  Pituitary                            0.004970
# 10 Brain-Substantianigra                0.004820
# 11 Ovary                                0.004780
# 12 Lung                                 0.004705
# 13 Kidney-Cortex                        0.004650
# 14 Brain-Hippocampus                    0.004630
# 15 SmallIntestine-TerminalIleum         0.004630
# 16 Breast-MammaryTissue                 0.004540
# 17 Uterus                               0.004515
# 18 Brain-Hypothalamus                   0.004450
# 19 Skin-NotSunExposed_Suprapubic_       0.004310
# 20 Brain-Cortex                         0.004290
# 21 Vagina                               0.004290
# 22 Adipose-Subcutaneous                 0.004220
# 23 Brain-Amygdala                       0.004160
# 24 Brain-Putamen_basalganglia_          0.004150
# 25 Skin-SunExposed_Lowerleg_            0.004140
# 26 Colon-Sigmoid                        0.004110
# 27 Brain-Caudate_basalganglia_          0.004070
# 28 Brain-Nucleusaccumbens_basalganglia_ 0.004065
# 29 Adipose-Visceral_Omentum_            0.004010
# 30 Colon-Transverse                     0.003955
# 31 Esophagus-GastroesophagealJunction   0.003910
# 32 Brain-Anteriorcingulatecortex_BA24_  0.003890
# 33 Brain-FrontalCortex_BA9_             0.003820
# 34 WholeBlood                           0.003730
# 35 MinorSalivaryGland                   0.003705
# 36 Esophagus-Muscularis                 0.003690
# 37 Artery-Tibial                        0.003570
# 38 Artery-Coronary                      0.003520
# 39 Stomach                              0.003450
# 40 Artery-Aorta                         0.003440
# 41 AdrenalGland                         0.003435
# 42 Heart-AtrialAppendage                0.003400
# 43 Liver                                0.003160
# 44 Cells-EBV-transformedlymphocytes     0.003110
# 45 Esophagus-Mucosa                     0.002960
# 46 Heart-LeftVentricle                  0.002650
# 47 Pancreas                             0.002460
# 48 Muscle-Skeletal                      0.002450
# 49 Cells-Culturedfibroblasts            0.001860

# %%
median_unprod_ratio_all_gtex <- ratios[tissue != "EUR", .(median_prod_ratio = median(unprodRatio)), by = tissue
    ][order(-median_prod_ratio)] %>% 
    pull(median_prod_ratio) %>% median

median_unprod_ratio_all_gtex
# Out:
# [1] 0.00414

# %%
p1  <- ratios %>% 
    ggplot() + geom_boxplot(aes(x = forcats::fct_reorder(tissue, -unprodRatio), y = unprodRatio, col = tissue), width = .3) +
        scale_y_continuous(labels = scales::percent_format(accuracy = .1)) +
        geom_hline(yintercept = median_unprod_ratio_all_gtex, linetype = 2, col = "black") +
        geom_text(aes(x = 45, y = median_unprod_ratio_all_gtex*1.01, label = median_unprod_ratio_all_gtex %>% scales::percent(accuracy = .01)), 
                  hjust = 0, vjust = 0, col = "black", size = 6) +
        labs(x = NULL, y = "Fraction of unproductive reads", 
             title = "Fraction of unproductive reads by tissue",
             subtitle = "clusters with ONLY unprod. introns are excluded from both numerators and denominators",
            ) +
        theme(legend.position = "none", axis.text.x = element_text(angle = 90, hjust = 1))

# %%
p2 <- ratios[, .(nsample = uniqueN(sample)), by = tissue] %>% 
    ggplot() + geom_col(aes(x = forcats::fct_reorder(tissue, -nsample), y = nsample, fill = tissue), width = .3) +
        scale_y_continuous(labels = scales::comma_format()) +
        labs(x = NULL, y = "Number of samples", 
             title = "Number of samples by tissue",
            ) +
        theme(legend.position = "none", axis.text.x = element_text(angle = 90, hjust = 1))

# %%
#| label: fig-unprodRatio-by-tissue
#| include: true
p1
# Out:
# plot without title

# %%
#| label: fig-nsample-by-tissue
#| include: true

p2
# Out:
# plot without title

# %%
ratios[, .(sample, unprodRatio, nsample, medUnprodRatio = median(unprodRatio)), by = tissue][sample(1:17329, 10)]
# Out:
#    tissue                         sample     unprodRatio nsample medUnprodRatio
# 1  Breast-MammaryTissue           GTEX-1R9PM 0.00434     459     0.004540
# 2  Colon-Sigmoid                  GTEX-WHWD  0.00395     373     0.004110
# 3  Spleen                         GTEX-1122O 0.00544     241     0.005230
# 4  Brain-FrontalCortex_BA9_       GTEX-1HSMO 0.00389     209     0.003820
# 5  Lung                           GTEX-12696 0.00457     578     0.004705
# 6  Stomach                        GTEX-1QP2A 0.00361     359     0.003450
# 7  Skin-NotSunExposed_Suprapubic_ GTEX-1K2DA 0.00502     604     0.004310
# 8  Muscle-Skeletal                GTEX-WHSE  0.00221     803     0.002450
# 9  Skin-SunExposed_Lowerleg_      GTEX-16XZY 0.00477     701     0.004140
# 10 Artery-Tibial                  GTEX-18A67 0.00395     663     0.003570

# %%
wrap_labels  <- function(x, y = 5) {str_wrap(str_replace_all(x, "[\\-]|(_.+_)", " "), y)}
wrap_labels("thisisavery_lon_gstring-thatneedstob-ewrapped", 10) %>% cat
# Out:
# thisisavery
# gstring
# thatneedstob
# ewrapped

# %%
labels = ratios[, .(nsample, med = median(unprodRatio)), by = tissue] %>% unique %>% 
    .[, .(tissue, nsample, med, tid = forcats::fct_reorder(tissue, -med) %>% as.integer)] %>% 
    .[order(tid)]

head(labels)
# Out:
#   tissue                        nsample med     tid
# 1 Testis                        361     0.00914 1
# 2 Brain-Cerebellum              241     0.00723 2
# 3 Brain-CerebellarHemisphere    215     0.00674 3
# 4 Brain-Spinalcord_cervicalc-1_ 159     0.00615 4
# 5 Thyroid                       653     0.00565 5
# 6 Prostate                      245     0.00563 6

# %%
label_x1 <- function(ids) {
    labels[tid == ids, tissue] %>% 
        str_replace_all("[\\-]|(_.+_)", " ") %>% 
        str_wrap(25)
}

label_x2 <- function(ids) {
    labels[tid == ids, nsample] 
}

label_x1(1)
label_x2(5)
# Out:
# [1] "Testis"
# [1] 653

# %%
point_scale <- function(x, newmin, newmax) {
  newmax  <- max(newmax)
  newmin  <- min(newmin)
  new_range <- abs(newmax - newmin) 
  old_range <- abs(max(x) - min(x))

  # Normalize the values between 0 and 1
  normalized_x <- (x - min(x)) / old_range

  # Scale the normalized values to the new range and offset by 0.5
  scaled_x <- normalized_x * new_range + newmin

  return(scaled_x)
}

# %%
point_scale(1:5, .5, 1.5)
# Out:
# [1] 0.50 0.75 1.00 1.25 1.50

# %%
df <- ratios[, .(sample, unprodRatio, nsample, med = median(unprodRatio),rk=rank(unprodRatio, ties.method = "first")), by = tissue
        ][, .(sample, unprodRatio, nsample, med, tissue = forcats::fct_reorder(tissue, -med), rk)
        ][, .(sample, tissue, unprodRatio, nsample, med, tissuei = as.integer(tissue), rk)
        ][, .(sample, unprodRatio, nsample, med, tissuei, rk, pointx = point_scale(rk, (tissuei - .5), tissuei+.5)), by = tissue
        ][order(tissuei, rk)]
df[str_detect(tissue, "Testis")]
# Out:
#     tissue sample     unprodRatio nsample med     tissuei rk  pointx
# 1   Testis GTEX-1JKYN 0.00516     361     0.00914 1        1  0.5000000
# 2   Testis GTEX-1AX8Z 0.00530     361     0.00914 1        2  0.5027778
# 3   Testis GTEX-S4Z8  0.00568     361     0.00914 1        3  0.5055556
# 4   Testis GTEX-12BJ1 0.00574     361     0.00914 1        4  0.5083333
# 5   Testis GTEX-1QAET 0.00586     361     0.00914 1        5  0.5111111
# 6   Testis GTEX-117YX 0.00588     361     0.00914 1        6  0.5138889
# 7   Testis GTEX-WY7C  0.00588     361     0.00914 1        7  0.5166667
# 8   Testis GTEX-1KXAM 0.00595     361     0.00914 1        8  0.5194444
# 9   Testis GTEX-1GMR2 0.00598     361     0.00914 1        9  0.5222222
# 10  Testis GTEX-1C6VS 0.00605     361     0.00914 1       10  0.5250000
# 11  Testis GTEX-ZLFU  0.00611     361     0.00914 1       11  0.5277778
# 12  Testis GTEX-13OW8 0.00616     361     0.00914 1       12  0.5305556
# 13  Testis GTEX-Y3I4  0.00629     361     0.00914 1       13  0.5333333
# 14  Testis GTEX-18A67 0.00633     361     0.00914 1       14  0.5361111
# 15  Testis GTEX-1H1DG 0.00633     361     0.00914 1       15  0.5388889
# 16  Testis GTEX-1E2YA 0.00642     361     0.00914 1       16  0.5416667
# 17  Testis GTEX-ZDTT  0.00642     361     0.00914 1       17  0.5444444
# 18  Testis GTEX-11DXY 0.00644     361     0.00914 1       18  0.5472222
# 19  Testis GTEX-1399T 0.00659     361     0.00914 1       19  0.5500000
# 20  Testis GTEX-1QP29 0.00667     361     0.00914 1       20  0.5527778
# 21  Testis GTEX-PLZ6  0.00668     361     0.00914 1       21  0.5555556
# 22  Testis GTEX-1GL5R 0.00674     361     0.00914 1       22  0.5583333
# 23  Testis GTEX-PLZ5  0.00685     361     0.00914 1       23  0.5611111
# 24  Testis GTEX-ZTX8  0.00687     361     0.00914 1       24  0.5638889
# 25  Testis GTEX-1399R 0.00692     361     0.00914 1       25  0.5666667
# 26  Testis GTEX-WFON  0.00694     361     0.00914 1       26  0.5694444
# 27  Testis GTEX-13QJ3 0.00696     361     0.00914 1       27  0.5722222
# 28  Testis GTEX-1K2DA 0.00700     361     0.00914 1       28  0.5750000
# 29  Testis GTEX-YB5E  0.00703     361     0.00914 1       29  0.5777778
# 30  Testis GTEX-145LT 0.00712     361     0.00914 1       30  0.5805556
# ⋮   ⋮      ⋮          ⋮           ⋮       ⋮       ⋮       ⋮   ⋮
# 332 Testis GTEX-17MF6 0.01080     361     0.00914 1       332 1.419444
# 333 Testis GTEX-WK11  0.01080     361     0.00914 1       333 1.422222
# 334 Testis GTEX-11WQC 0.01081     361     0.00914 1       334 1.425000
# 335 Testis GTEX-1KANB 0.01081     361     0.00914 1       335 1.427778
# 336 Testis GTEX-1JN6P 0.01084     361     0.00914 1       336 1.430556
# 337 Testis GTEX-XAJ8  0.01084     361     0.00914 1       337 1.433333
# 338 Testis GTEX-12696 0.01086     361     0.00914 1       338 1.436111
# 339 Testis GTEX-17HII 0.01093     361     0.00914 1       339 1.438889
# 340 Testis GTEX-1PIIG 0.01094     361     0.00914 1       340 1.441667
# 341 Testis GTEX-RVPV  0.01097     361     0.00914 1       341 1.444444
# 342 Testis GTEX-1MCQQ 0.01101     361     0.00914 1       342 1.447222
# 343 Testis GTEX-17EVP 0.01105     361     0.00914 1       343 1.450000
# 344 Testis GTEX-1H4P4 0.01107     361     0.00914 1       344 1.452778
# 345 Testis GTEX-Z93S  0.01110     361     0.00914 1       345 1.455556
# 346 Testis GTEX-111VG 0.01115     361     0.00914 1       346 1.458333
# 347 Testis GTEX-11NV4 0.01117     361     0.00914 1       347 1.461111
# 348 Testis GTEX-11TUW 0.01120     361     0.00914 1       348 1.463889
# 349 Testis GTEX-1IKJJ 0.01122     361     0.00914 1       349 1.466667
# 350 Testis GTEX-1C6VR 0.01136     361     0.00914 1       350 1.469444
# 351 Testis GTEX-1I1GV 0.01136     361     0.00914 1       351 1.472222
# 352 Testis GTEX-1JMLX 0.01138     361     0.00914 1       352 1.475000
# 353 Testis GTEX-1GTWX 0.01139     361     0.00914 1       353 1.477778
# 354 Testis GTEX-1EH9U 0.01141     361     0.00914 1       354 1.480556
# 355 Testis GTEX-1LVA9 0.01141     361     0.00914 1       355 1.483333
# 356 Testis GTEX-1IOXB 0.01143     361     0.00914 1       356 1.486111
# 357 Testis GTEX-11ZUS 0.01150     361     0.00914 1       357 1.488889
# 358 Testis GTEX-1LB8K 0.01151     361     0.00914 1       358 1.491667
# 359 Testis GTEX-1A3MX 0.01156     361     0.00914 1       359 1.494444
# 360 Testis GTEX-1HKZK 0.01217     361     0.00914 1       360 1.497222
# 361 Testis GTEX-1C64N 0.01231     361     0.00914 1       361 1.500000

# %%
p3 <- ggplot(df) +
        geom_point(aes(x = pointx, y = unprodRatio), color = 'midnightblue', alpha = .1) +
        geom_tile(aes(x = tissuei, y = med), color = 'firebrick', fill= 'firebrick', height = 5e-5, width = .9) +
        scale_x_continuous(
            breaks = unique(df$tissuei), labels = label_x1, expand = c(0, .5),
            sec.axis = sec_axis(~., breaks = unique(df$tissuei), labels = label_x2,
                            guide = guide_axis(angle = 0)
                            )
            ) +
        scale_y_continuous(labels = scales::percent_format(accuracy = .1)) +
        labs(x = "Tissue / Number of Samples",
            y = "Fraction of unproductive reads"
            )

# %%
options(repr.plot.width = 17, repr.plot.height = 6, repr.plot.res = 180)
p3 + theme(legend.position = "none", axis.text.x = element_text(angle = 90, hjust = 1, size = 11))
# Out:
# plot without title

# %%
medianUP <- ratios[, .(nsample, med = median(unprodRatio)), by = tissue] %>% unique %>% .[order(-med)]

# %%
dim(medianUP)
medianUP[1:3]
# Out:
# [1] 49  3
#   tissue                     nsample med
# 1 Testis                     361     0.00914
# 2 Brain-Cerebellum           241     0.00723
# 3 Brain-CerebellarHemisphere 215     0.00674

# %%
# old median unprod reads ratio using naive annotation method in older versions of leafcutter2
oldMedians <- readxl::read_excel("../data/ExtractFractions/GTEx-median-unprodReads-naivemethod.xlsx")

# %%
oldMedians[1:3,]
# Out:
#   tissue                     nsample medUPreads
# 1 Testis                     361     0.01095
# 2 Brain-Cerebellum           241     0.00863
# 3 Brain-CerebellarHemisphere 215     0.00810

# %%
inner_join(medianUP[, .(tissue, nsample, medUPreads=med)], oldMedians, by = "tissue", suffix = c("_new", "_old"))  %>% 
    pivot_longer(cols = c(medUPreads_new, medUPreads_old), names_to = "method", values_to = "medUPreads") %>% 
    ggplot() + 
        geom_point(aes(x = forcats::fct_reorder(tissue, -medUPreads), y = medUPreads, col = method), size = 3) +
        scale_y_continuous(labels = scales::percent_format(accuracy = .1)) +
        theme(legend.position = "bottom", axis.text.x = element_text(angle = 90, hjust = 1))
# Out:
# plot without title

# %%
inner_join(medianUP[, .(tissue, nsample, medUPreads=med)], oldMedians, by = "tissue", suffix = c("_new", "_old"))  %>% 
    .[, .(tissue, nsample_new, medUPreads_new, delta = (medUPreads_new - medUPreads_old), change_perc = (medUPreads_new - medUPreads_old) / medUPreads_old
    )]  %>% pull(delta) %>% summary
# Out:
#      Min.   1st Qu.    Median      Mean   3rd Qu.      Max.
# -0.001810 -0.001135 -0.001020 -0.001029 -0.000915 -0.000550
