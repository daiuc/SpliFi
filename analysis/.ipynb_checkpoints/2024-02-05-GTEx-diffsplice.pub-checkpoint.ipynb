# %% [raw]
# ---
# title: "GTEx differential splicing"
# date: 2024-2-12
# author: "Chao Dai"
# code-fold: true
# execute:
#   warning: false
#   message: false
#   echo: false
#   include: false
# categories:
#   - "GTEx"
#   - "Differential splicing"
# jupyter:
#     language: r
# ---

# %%
setwd("~/cdai/SpliFi/analysis")

# %%
suppressMessages(library(tidyverse))
suppressMessages(library(data.table))

# %%
library(patchwork)
library(ggtext)

# %%
library(magrittr)
# Out:
# Attaching package: ‘magrittr’
#
#
# The following object is masked from ‘package:purrr’:
#
#     set_names
#
#
# The following object is masked from ‘package:tidyr’:
#
#     extract

# %%
suppressMessages(library(bedtoolsr))
suppressMessages(library(GenomicRanges))

# %%
options(repr.plot.width=5, repr.plot.height=5, repr.plot.res=180)

# %%
suppressMessages(library(cowplot))
theme_set(theme_cowplot(font_size = 14))

# %%
genes <- fread('/project2/yangili1/cdai/annotations/hg38/gencode.v43.primary_assembly.annotation.csv.gz')
genes <- genes[feature == "gene" & gene_type == "protein_coding", .(seqname, start, end, gene_name, gene_id, strand)] %>% unique

# %%
genes <- makeGRangesFromDataFrame(genes, keep.extra.columns = T, ignore.strand = F)

# %%
length(genes)
head(genes)
# Out:
# [1] 20042
# GRanges object with 6 ranges and 2 metadata columns:
#       seqnames        ranges strand |   gene_name            gene_id
#          <Rle>     <IRanges>  <Rle> | <character>        <character>
#   [1]     chr1   65419-71585      + |       OR4F5  ENSG00000186092.7
#   [2]     chr1 450740-451678      - |      OR4F29  ENSG00000284733.2
#   [3]     chr1 685716-686654      - |      OR4F16  ENSG00000284662.2
#   [4]     chr1 923923-944575      + |      SAMD11 ENSG00000187634.13
#   [5]     chr1 944203-959309      - |       NOC2L ENSG00000188976.11
#   [6]     chr1 960584-965719      + |      KLHL17 ENSG00000187961.15
#   -------
#   seqinfo: 25 sequences from an unspecified genome; no seqlengths

# %% [markdown]
# # Introduction
#
#
# Differential splicing analyses in GTEx
#
# Contrasts:
#
# - Brain-Cerebellum v. Cells-EBV-transformedlymphocytes
# - Brain-Cerebellum v. Kidney-Cortex
# - Brain-Cerebellum v. Liver
#
#
# Use annotated noise_by_intron files to get labeling of introns

# %%
comps <- c("Brain-Cerebellum_v_Cells-EBV-transformedlymphocytes",
            "Brain-Cerebellum_v_Kidney-Cortex",
            "Brain-Cerebellum_v_Liver",
            "Liver_v_Kidney-Cortex",
            "Liver_v_Muscle-Skeletal"
)
pvals.f <- paste("../code/results/ds/GTEx/", comps, "/ds_cluster_significance.txt", sep="")
betas.f <- paste("../code/results/ds/GTEx/", comps, "/ds_effect_sizes.txt", sep="")
introns.f <- paste("../code/results/ds/GTEx/", comps, "/ds_perind.counts.noise_by_intron.gz", sep="")

names(pvals.f) <- comps
names(betas.f) <- comps
names(introns.f) <- comps

# %%
getIntronLabels <- function(f) {
    cmd <- paste0('zcat ', f, " | awk '{print $1}'", collapse = " ")
    introns <- fread(cmd = cmd)
    introns <- introns[, .(intron = str_sub(chrom, 1, -4), 
                           cluster = str_split(chrom, ":") %>% map_chr(~paste(.x[1], .x[4], sep=":")),
                           itype = str_sub(chrom, -2, -1)
                          )]
    introns[, ctype := paste(sort(unique(itype)), sep="", collapse=","), by = cluster]
    
    return(introns)
}

# %%
pvals <- map(pvals.f, fread)
betas <- map(betas.f, fread)
introns <- map(introns.f, getIntronLabels)

# %%
pvals[[1]][1:3]
betas[[1]][1:3]
introns[[1]][1:3]
# Out:
#   status                  loglr    df p             cluster
# 1 <=1 junction in cluster       NA NA            NA chr1:clu_10_+
# 2 <=1 junction in cluster       NA NA            NA chr1:clu_1000_+
# 3 Success                 571.9535  3 1.084591e-247 chr1:clu_1002_+
#   p.adjust
# 1            NA
# 2            NA
# 3 1.558616e-246
#   intron                            logef      Brain-Cerebellum
# 1 chr1:75724817:75728388:clu_1002_+  0.7081498 0.003776209
# 2 chr1:75724817:75728400:clu_1002_+  0.3671185 0.376768275
# 3 chr1:75724817:75732643:clu_1002_+ -1.3719115 0.137389785
#   Cells-EBV-transformedlymphocytes deltapsi
# 1 0.006208044                       0.002431835
# 2 0.440418013                       0.063649738
# 3 0.028215910                      -0.109173875
#   intron                     cluster      itype ctype
# 1 chr1:779092:781936:clu_3_+ chr1:clu_3_+ IN    IN
# 2 chr1:779092:803918:clu_3_+ chr1:clu_3_+ IN    IN
# 3 chr1:804222:804775:clu_5_+ chr1:clu_5_+ IN    IN

# %%
if (all(names(pvals) == names(introns))) {
    print("do")
    pvals <- map2(
                pvals,
                introns,
                \(x,y) {
                    left_join(x, unique(y[, .(cluster, ctype)]), by = "cluster")
                }
            )
}
# Out:
# [1] "do"

# %%
if (all(names(betas) == names(introns))) {
    print("do")
    betas <- map2(
                betas,
                introns,
                \(x,y) {
                    left_join(x, unique(y[, .(intron, itype, ctype)]), by = "intron")
                }
            )
}
# Out:
# [1] "do"

# %%
names(introns)
# Out:
# [1] "Brain-Cerebellum_v_Cells-EBV-transformedlymphocytes"
# [2] "Brain-Cerebellum_v_Kidney-Cortex"
# [3] "Brain-Cerebellum_v_Liver"
# [4] "Liver_v_Kidney-Cortex"
# [5] "Liver_v_Muscle-Skeletal"

# %% [markdown]
# # Number of significant intron clusters
#
# set FDR=0.1

# %%
FDR=.1

# %%
head(pvals[[1]])
# Out:
#   status                  loglr    df p             cluster
# 1 <=1 junction in cluster       NA NA            NA chr1:clu_10_+
# 2 <=1 junction in cluster       NA NA            NA chr1:clu_1000_+
# 3 Success                 571.9535  3 1.084591e-247 chr1:clu_1002_+
# 4 Success                 858.4211  5  0.000000e+00 chr1:clu_1003_+
# 5 Success                 389.6304  4 2.384755e-167 chr1:clu_1004_+
# 6 <=1 junction in cluster       NA NA            NA chr1:clu_1005_+
#   p.adjust      ctype
# 1            NA PR
# 2            NA PR
# 3 1.558616e-246 PR
# 4  0.000000e+00 PR
# 5 2.068752e-166 PR,UP
# 6            NA PR

# %%
head(pvals[[1]])$df %>% summary
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.    NA's
#     3.0     3.5     4.0     4.0     4.5     5.0       3

# %%
imap_dfr(
    pvals, 
    \(x, y) {
        x[, .(.N, comps = y), by = .(passFDR = `p.adjust` < FDR)]
    }
) %>% 
.[, .(comps, passFDR, N, P = N/sum(N)), by = comps]
# Out:
#    comps
# 1  Brain-Cerebellum_v_Cells-EBV-transformedlymphocytes
# 2  Brain-Cerebellum_v_Cells-EBV-transformedlymphocytes
# 3  Brain-Cerebellum_v_Cells-EBV-transformedlymphocytes
# 4  Brain-Cerebellum_v_Kidney-Cortex
# 5  Brain-Cerebellum_v_Kidney-Cortex
# 6  Brain-Cerebellum_v_Kidney-Cortex
# 7  Brain-Cerebellum_v_Liver
# 8  Brain-Cerebellum_v_Liver
# 9  Brain-Cerebellum_v_Liver
# 10 Liver_v_Kidney-Cortex
# 11 Liver_v_Kidney-Cortex
# 12 Liver_v_Kidney-Cortex
# 13 Liver_v_Muscle-Skeletal
# 14 Liver_v_Muscle-Skeletal
# 15 Liver_v_Muscle-Skeletal
#    comps                                               passFDR N     P
# 1  Brain-Cerebellum_v_Cells-EBV-transformedlymphocytes    NA   14233 0.3449254
# 2  Brain-Cerebellum_v_Cells-EBV-transformedlymphocytes  TRUE   22917 0.5553751
# 3  Brain-Cerebellum_v_Cells-EBV-transformedlymphocytes FALSE    4114 0.0996995
# 4  Brain-Cerebellum_v_Kidney-Cortex                       NA   13816 0.3274477
# 5  Brain-Cerebellum_v_Kidney-Cortex                     TRUE   21589 0.5116726
# 6  Brain-Cerebellum_v_Kidney-Cortex                    FALSE    6788 0.1608798
# 7  Brain-Cerebellum_v_Liver                               NA   14638 0.3536518
# 8  Brain-Cerebellum_v_Liver                             TRUE   21718 0.5247034
# 9  Brain-Cerebellum_v_Liver                            FALSE    5035 0.1216448
# 10 Liver_v_Kidney-Cortex                                TRUE   14595 0.3560103
# 11 Liver_v_Kidney-Cortex                                  NA   13775 0.3360084
# 12 Liver_v_Kidney-Cortex                               FALSE   12626 0.3079813
# 13 Liver_v_Muscle-Skeletal                                NA   13416 0.3353916
# 14 Liver_v_Muscle-Skeletal                              TRUE   21523 0.5380615
# 15 Liver_v_Muscle-Skeletal                             FALSE    5062 0.1265468

# %%
imap_dfr(
    pvals, 
    \(x, y) {
        x[, .(.N, comps = y), by = .(ctype, passFDR = `p.adjust` < FDR)]
    }
) %>% 
.[, .(ctype, passFDR, N, P = scales::percent(N/sum(N), .1)), by = comps] %>% 
.[ctype %in% c("PR", "PR,UP") & passFDR == T] %>% 
.[order(comps, -N)]
# Out:
#    comps                                               ctype passFDR N
# 1  Brain-Cerebellum_v_Cells-EBV-transformedlymphocytes PR    TRUE    12121
# 2  Brain-Cerebellum_v_Cells-EBV-transformedlymphocytes PR,UP TRUE     9457
# 3  Brain-Cerebellum_v_Kidney-Cortex                    PR    TRUE    11522
# 4  Brain-Cerebellum_v_Kidney-Cortex                    PR,UP TRUE     8696
# 5  Brain-Cerebellum_v_Liver                            PR    TRUE    11706
# 6  Brain-Cerebellum_v_Liver                            PR,UP TRUE     8767
# 7  Liver_v_Kidney-Cortex                               PR    TRUE     7907
# 8  Liver_v_Kidney-Cortex                               PR,UP TRUE     5800
# 9  Liver_v_Muscle-Skeletal                             PR    TRUE    12020
# 10 Liver_v_Muscle-Skeletal                             PR,UP TRUE     8281
#    P
# 1  29.4%
# 2  22.9%
# 3  27.3%
# 4  20.6%
# 5  28.3%
# 6  21.2%
# 7  19.3%
# 8  14.1%
# 9  30.0%
# 10 20.7%

# %%
relabelLong <- function(x, len=20) {
    str_replace_all(x, "[-_]", " ") %>% 
    str_wrap(len)
}

# %%
relabelLong("Brain-Cerebellum_v_Cells-EBV-transformedlymphocytes")
# Out:
# [1] "Brain Cerebellum\nv Cells EBV\ntransformedlymphocytes"

# %%
options(repr.plot.width = 7, repr.plot.height = 5, repr.plot.res = 180)

# %%
imap_dfr(
    pvals,
    \(x, y) {
        x[, .(.N, comps = y), by = .(ctype, passFDR = `p.adjust` < FDR)
        ][, .(N, ctype, comps, passFDR = as.integer(passFDR))
        ][, .(N, ctype, comps, passFDR = case_when(
            passFDR == 1 ~ "significant",
            passFDR == 0 ~ "not significant",
            TRUE ~ "failed to test"
        ))] %>% 
        .[, .(ctype, N, P = N/sum(N), passFDR), by = comps] %>% 
        .[ctype %in% c("PR", "PR,UP")]
    }
 ) %>%
    ggplot() + geom_col(aes(x = comps, y = P, fill = forcats::fct_reorder(passFDR, -N)), position = "dodge") +
        geom_text(aes(x = comps, y = P + .02, label = N, hjust = passFDR), size = 3) +
        scale_x_discrete(labels = relabelLong) +
        scale_y_continuous(labels = scales::percent) +
        scale_fill_brewer(name = NULL, palette = "Blues", direction = -1) +
        labs(x = NULL, y = "% of clusters", title = "Significant diff. spliced clusters") +
        theme(axis.text.x = element_text(angle = 90, hjust = 1, vjust = .5)) +
        facet_wrap(~ctype)
# Out:
# plot without title

# %% [markdown]
# # Effect sizes

# %%
# significant cluster ids

sig.clusters <- map(
    pvals, 
    \(x, y) {
        x[`p.adjust` < FDR, cluster]
    }
)

# %%
betas <- map(betas, ~.x[, cluster := (str_split(intron, ":") %>% map_chr(~paste(.x[1], .x[4], sep=":")))])
# Out:
# Warning message in `[.data.table`(.x, , `:=`(cluster, (str_split(intron, ":") %>% :
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”
# Warning message in `[.data.table`(.x, , `:=`(cluster, (str_split(intron, ":") %>% :
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”
# Warning message in `[.data.table`(.x, , `:=`(cluster, (str_split(intron, ":") %>% :
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”
# Warning message in `[.data.table`(.x, , `:=`(cluster, (str_split(intron, ":") %>% :
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”
# Warning message in `[.data.table`(.x, , `:=`(cluster, (str_split(intron, ":") %>% :
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”

# %%
pvals[[1]][str_detect(cluster, "clu_1002_")]
# Out:
#   status  loglr    df p             cluster         p.adjust      ctype
# 1 Success 571.9535 3  1.084591e-247 chr1:clu_1002_+ 1.558616e-246 PR

# %%
names(betas)
names(sig.clusters)
# Out:
# [1] "Brain-Cerebellum_v_Cells-EBV-transformedlymphocytes"
# [2] "Brain-Cerebellum_v_Kidney-Cortex"
# [3] "Brain-Cerebellum_v_Liver"
# [4] "Liver_v_Kidney-Cortex"
# [5] "Liver_v_Muscle-Skeletal"
# [1] "Brain-Cerebellum_v_Cells-EBV-transformedlymphocytes"
# [2] "Brain-Cerebellum_v_Kidney-Cortex"
# [3] "Brain-Cerebellum_v_Liver"
# [4] "Liver_v_Kidney-Cortex"
# [5] "Liver_v_Muscle-Skeletal"

# %%
if (all(names(betas) == names(sig.clusters))) {
    betas.sig <- map2(betas, sig.clusters, ~.x[cluster %in% .y])
}

# %%
sig.clusters[[2]] %>% head
# Out:
# [1] "chr1:clu_1002_+" "chr1:clu_1003_+" "chr1:clu_1004_+" "chr1:clu_1006_+"
# [5] "chr1:clu_1007_+" "chr1:clu_1011_+"

# %%
betas.sig[[2]] %>% head
# Out:
#   intron                            logef      Brain-Cerebellum Kidney-Cortex
# 1 chr1:75724817:75728388:clu_1002_+  0.4201798 0.004365541      0.0054051575
# 2 chr1:75724817:75728400:clu_1002_+  0.3394861 0.378081032      0.4318275142
# 3 chr1:75724817:75732643:clu_1002_+ -1.0486389 0.134640866      0.0383749030
# 4 chr1:75728488:75732643:clu_1002_+  0.2889731 0.482912561      0.5243924253
# 5 chr1:75732922:75733050:clu_1003_+ -1.3547423 0.014904773      0.0008993951
# 6 chr1:75732922:75733527:clu_1003_+  1.6555048 0.413167514      0.5059236479
#   deltapsi     itype ctype cluster
# 1  0.001039616 PR    PR    chr1:clu_1002_+
# 2  0.053746483 PR    PR    chr1:clu_1002_+
# 3 -0.096265963 PR    PR    chr1:clu_1002_+
# 4  0.041479865 PR    PR    chr1:clu_1002_+
# 5 -0.014005378 PR    PR    chr1:clu_1003_+
# 6  0.092756134 PR    PR    chr1:clu_1003_+

# %%
# map(pvals, dim) %>% print
map(sig.clusters, length) %>% print
map(betas.sig, dim) %>% print
# Out:
# $`Brain-Cerebellum_v_Cells-EBV-transformedlymphocytes`
# [1] 22917
#
# $`Brain-Cerebellum_v_Kidney-Cortex`
# [1] 21589
#
# $`Brain-Cerebellum_v_Liver`
# [1] 21718
#
# $`Liver_v_Kidney-Cortex`
# [1] 14595
#
# $`Liver_v_Muscle-Skeletal`
# [1] 21523
#
# $`Brain-Cerebellum_v_Cells-EBV-transformedlymphocytes`
# [1] 83439     8
#
# $`Brain-Cerebellum_v_Kidney-Cortex`
# [1] 77828     8
#
# $`Brain-Cerebellum_v_Liver`
# [1] 76742     8
#
# $`Liver_v_Kidney-Cortex`
# [1] 54404     8
#
# $`Liver_v_Muscle-Skeletal`
# [1] 74646     8

# %%
betas.sig[[3]] %>% 
    .[, .(intron, deltapsi, rk = frank(-abs(deltapsi)))] %>% 
    .[rk < 50] %>% head
# Out:
#   intron                                deltapsi   rk
# 1 chr1:113681336:113682896:clu_1258_+    0.9456466 30.0
# 2 chr1:10272306:10275427:clu_169_+       0.9365349 48.0
# 3 chr10:69895576:69897474:clu_23318_+    0.9462744 28.5
# 4 chr10:69895576:69898696:clu_23318_+   -0.9462744 28.5
# 5 chr10:112182891:112183692:clu_24573_- -0.9750666  9.0
# 6 chr11:46659485:46665382:clu_25169_+    0.9556514 22.0

# %%
hist1 <- imap_dfr(betas.sig, ~.x[, .(intron, deltapsi, grp = .y)]) %>% 
    ggplot() + geom_histogram(aes(x = abs(deltapsi), fill = grp), binwidth = .01) +
    scale_fill_brewer(name=NULL, palette = "Accent", labels = relabelLong) + 
    theme_bw() +
    theme(legend.position = "right", panel.grid = element_blank())

# %%
hist1
# Out:
# plot without title

# %%
gg.gap::gg.gap(hist1, ylim = c(0, 8e4), 
               segments = list(c(500, 2000), c(1e4, 1.2e4)), 
               tick_width = c(100, 3e3, 5e4),
               rel_heights = c(.7, 0, .5, 0, .3)
              )
# Out:
# plot without title

# %%
imap_dfr(betas.sig, ~.x[, .(intron, deltapsi, grp = .y)]) %>% 
    ggplot() + stat_ecdf(aes(x = abs(deltapsi), color = grp)) +
        scale_color_brewer(type = "qual", palette = 2, direction = -1, label = relabelLong, name = NULL) +
        labs(title = "dtPSI (all significant introns)") +
        scale_x_sqrt() +
        theme_bw() +
        theme(legend.position = "bottom")
# Out:
# plot without title

# %%
betas.sig[[1]][1:3]
# Out:
#   intron                            logef      Brain-Cerebellum
# 1 chr1:75724817:75728388:clu_1002_+  0.7081498 0.003776209
# 2 chr1:75724817:75728400:clu_1002_+  0.3671185 0.376768275
# 3 chr1:75724817:75732643:clu_1002_+ -1.3719115 0.137389785
#   Cells-EBV-transformedlymphocytes deltapsi     itype ctype cluster
# 1 0.006208044                       0.002431835 PR    PR    chr1:clu_1002_+
# 2 0.440418013                       0.063649738 PR    PR    chr1:clu_1002_+
# 3 0.028215910                      -0.109173875 PR    PR    chr1:clu_1002_+

# %%
hist2 <- imap_dfr(betas.sig, ~.x[ctype %in% c("PR", "PR,UP"), .(intron, deltapsi, itype, ctype, grp = .y)]) %>% 
    ggplot() + geom_histogram(aes(x = abs(deltapsi), fill = itype), binwidth = .01) +
    scale_fill_brewer(name=NULL, palette = "Accent", labels = relabelLong) + 
    theme_bw() +
    theme(legend.position = "bottom", panel.grid = element_blank()) +
    facet_wrap(~grp, nrow = 1)

# %%
options(repr.plot.width = 15, repr.plot.height = 4, repr.plot.res = 180)

# %%
hist2
# Out:
# plot without title

# %%
gg.gap::gg.gap(hist2, ylim = c(0, 2e4), 
               segments = list(c(400,1000), c(6000,7000)), 
               tick_width = c(100, 1e3, 5e3),
               rel_heights = c(.6, 0, .5, 0, .4)
              )
# Out:
# plot without title

# %%
hist2.2 <- imap_dfr(betas.sig, ~.x[ctype %in% c("PR", "PR,UP"), .(intron, ctype, itype, deltapsi, grp = .y)]) %>% 
    ggplot() + stat_ecdf(aes(x = abs(deltapsi), color = itype)) +
        scale_color_brewer(type = "qual", palette = 2, direction = -1, label = c(PR="Productive", UP="Unproductive"), name = NULL) +
        scale_x_sqrt(name = expr(paste("abs(", Delta, "psi)"))) +
        labs(title = expr(paste("Distribution of ", Delta, "psi"))) +
        theme_bw() +
        theme(legend.position = "bottom"
             ) +
        facet_wrap(~grp, nrow=1)

# %%
hist2.2
# Out:
# plot without title

# %% [markdown]
# **Interpretation:**
#
# - productive clusters generally have larger psi changes than unproductive clusters.
#     - because PR clusters reflect changes from 1 protein coding isoform to another coding isform, while UP clusters include ones that change from protein coding to unproductive. The change to unproductive is more moderate?
#     - note, UP clusters must include protein coding introns, sometimes more than 1. So it's possible that differential spliced UP clusters are still clusters that shift between 1 protein coding iso to another protein isoform.

# %% [markdown]
# **PR Clusters:**
# - These clusters are easy to label. Since there are only PR introns, the differential splicing of these clusters change it from 1 protein coding isoform to another.
# - see table below:

# %%
betas.sig[[1]][ctype == 'PR'][cluster %in% c('chr1:clu_104_+', 'chr9:clu_22622_-')]
# Out:
#   intron                               logef      Brain-Cerebellum
# 1 chr1:5992788:5995862:clu_104_+       -0.1611220 0.004499482
# 2 chr1:5992788:6018634:clu_104_+       -0.6068769 0.036149809
# 3 chr1:5992788:6040516:clu_104_+       -1.8457047 0.918596071
# 4 chr1:6018835:6040516:clu_104_+       -1.8455455 0.034442479
# 5 chr1:6026445:6040516:clu_104_+        4.4592491 0.006312159
# 6 chr9:109217145:109243617:clu_22622_- -4.2596491 0.980585671
# 7 chr9:109241809:109243617:clu_22622_-  4.2596491 0.019414329
#   Cells-EBV-transformedlymphocytes deltapsi      itype ctype cluster
# 1 0.005322675                       0.0008231924 PR    PR    chr1:clu_104_+
# 2 0.027383218                      -0.0087665904 PR    PR    chr1:clu_104_+
# 3 0.201598343                      -0.7169977280 PR    PR    chr1:clu_104_+
# 4 0.007560072                      -0.0268824074 PR    PR    chr1:clu_104_+
# 5 0.758135692                       0.7518235334 PR    PR    chr1:clu_104_+
# 6 0.009979827                      -0.9706058441 PR    PR    chr9:clu_22622_-
# 7 0.990020173                       0.9706058441 PR    PR    chr9:clu_22622_-

# %% [markdown]
# **UP Clusters:**
# - if there is only 1 PR intron, then the changes have to go between the PR intron to 1 or more UP introns
# - if there are more than 1 PR introns, then the changes can
#     - go between the PR introns, which is not inducing NMD
#     - go from PR introns to UP introns

# %%
betas[[1]][ctype == 'PR,UP'] %>% 
    .[, .(intron, logef, `Brain-Cerebellum`, `Cells-EBV-transformedlymphocytes`,
          deltapsi, itype, ctype, 
          nPR = sum(str_detect(itype, "PR")),
          nUP = sum(str_detect(itype, 'UP'))
         ), by = cluster] %>% 
    .[, .(cluster, nPR, nUP)] %>% unique %>% 
    melt(id.vars = "cluster", variable.name = "type", value.name = "nintrons") %>% 
    ggplot() + stat_ecdf(aes(nintrons, color = type)) +
        scale_x_continuous(limits = c(0,20), breaks = seq(0,20,1), labels = seq(0,20,1)) +
        labs(title = "Number of PR or UP introns per cluster (from all introns)")
# Out:
# Warning message:
# “Removed 4 rows containing non-finite values (`stat_ecdf()`).”
# plot without title

# %%
betas.sig[[1]][ctype == 'PR,UP'] %>% 
    .[, .(intron, logef, `Brain-Cerebellum`, `Cells-EBV-transformedlymphocytes`,
          deltapsi, itype, ctype, 
          nPR = sum(str_detect(itype, "PR")),
          nUP = sum(str_detect(itype, 'UP'))
         ), by = cluster] %>% 
    .[, .(cluster, nPR, nUP)] %>% unique %>% 
    melt(id.vars = "cluster", variable.name = "type", value.name = "nintrons") %>% 
    ggplot() + stat_ecdf(aes(nintrons, color = type)) +
        scale_x_continuous(limits = c(0,20), breaks = seq(0,20,1), labels = seq(0,20,1)) +
        labs(title = "Number of PR or UP introns per cluster (from DS sig. introns)")
# Out:
# Warning message:
# “Removed 4 rows containing non-finite values (`stat_ecdf()`).”
# plot without title

# %% [markdown]
# just look at effect sizes from introns that are significantly ds
#
# DS logic:
# - `if ctype == 'PR': dstype = 'AS-NMD'`
# - `if ctype == 'PR,UP' AND nPR == 1: dstype = 'AS-NMD'`
# - `if ctype == PR,UP' AND nPR > 1 AND total abs(deltapsi) of PR introns < total abs(deltapsi) of UP introns: dstype = 'AS-NMD'`
# - Otherwise, all ctype == 'PR', or 'PR,UP' clusters are 'AS-PR', alternative isoform for protein coding transcripts

# %% [markdown]
# **Table below shows `PR,UP` clusters with >1 PR introns**
#
# - use sum of abs(deltapsi) by intron type (PR vs. UP)
# - if sum(abs(deltapsi)) of PR introns > than those of UP introns, it means that
# most introns that have significant change are PR introns, thus consider this cluster
# as largely alternative splicing for protein coding isoforms
# - otherwise, it means AS PR introns change to UP introns, thus induce AS-NMD

# %%
ds_tbd[1:20]
# Out:
# Error in eval(expr, envir, enclos): object 'ds_tbd' not found
# Traceback:

# %%
labelClusterDStype <- function(dt) {
    # dt: significant introns in effect size data.table

    # ensure only "PR", "PR,UP" ctypes
    dt <- dt[ctype %in% c('PR', 'PR,UP')]
    dt[, nPR := sum(str_detect(itype, 'PR')), by = cluster] # compute number of PR introns per cluster
    # label dstype
    dt[, dstype1 := case_when(
        ctype == 'PR' ~ 'AS-PR',
        ctype == 'PR,UP' & nPR == 1 ~ 'AS-NMD',
        TRUE ~ 'TBD'
    )]
    # subset dt where dstype1 == 'TBD'
    dt2 <- dt[dstype1 == 'TBD', .(cluster, intron, itype, ctype, dstype1, deltapsi)
             ][, .(adpsi = sum(abs(deltapsi))), by = .(cluster, itype)] %>% # compute abs(deltapsi) by cluster, introntype
            dcast(cluster~itype, value.var = 'adpsi') %>%
            .[, .(cluster, PR, UP, dstype2 = if_else(PR > UP, "AS-PR", "AS-NMD"))] # label dstype based on which has larger abs(deltapsi)
    
    dt <- left_join(dt, dt2[, .(cluster, dstype2)], by = 'cluster') # bring in dstype2 for TBD introns
    dt[, dstype := if_else(dstype1 == "TBD", dstype2, dstype1)]
    dt <- dt[, -c("dstype1", "dstype2")]
    return(dt)
}

# %%
# annotated effect size dataframes
betas.sig2 <- map(betas.sig, labelClusterDStype)
# Out:
# Warning message in `[.data.table`(dt, , `:=`(dstype, if_else(dstype1 == "TBD", dstype2, :
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”
# Warning message in `[.data.table`(dt, , `:=`(dstype, if_else(dstype1 == "TBD", dstype2, :
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”
# Warning message in `[.data.table`(dt, , `:=`(dstype, if_else(dstype1 == "TBD", dstype2, :
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”
# Warning message in `[.data.table`(dt, , `:=`(dstype, if_else(dstype1 == "TBD", dstype2, :
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”
# Warning message in `[.data.table`(dt, , `:=`(dstype, if_else(dstype1 == "TBD", dstype2, :
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”

# %%
betas.sig2[[1]] %>% head
# Out:
#   intron                            logef      Brain-Cerebellum
# 1 chr1:75724817:75728388:clu_1002_+  0.7081498 0.003776209
# 2 chr1:75724817:75728400:clu_1002_+  0.3671185 0.376768275
# 3 chr1:75724817:75732643:clu_1002_+ -1.3719115 0.137389785
# 4 chr1:75728488:75732643:clu_1002_+  0.2966433 0.482065731
# 5 chr1:75732922:75733050:clu_1003_+ -1.0966370 0.014190861
# 6 chr1:75732922:75733527:clu_1003_+  2.0576235 0.412621026
#   Cells-EBV-transformedlymphocytes deltapsi     itype ctype cluster         nPR
# 1 0.0062080438                      0.002431835 PR    PR    chr1:clu_1002_+ 4
# 2 0.4404180135                      0.063649738 PR    PR    chr1:clu_1002_+ 4
# 3 0.0282159100                     -0.109173875 PR    PR    chr1:clu_1002_+ 4
# 4 0.5251580327                      0.043092302 PR    PR    chr1:clu_1002_+ 4
# 5 0.0007684111                     -0.013422450 PR    PR    chr1:clu_1003_+ 6
# 6 0.5236174763                      0.110996450 PR    PR    chr1:clu_1003_+ 6
#   dstype
# 1 AS-PR
# 2 AS-PR
# 3 AS-PR
# 4 AS-PR
# 5 AS-PR
# 6 AS-PR

# %%
imap_dfr(betas.sig2, ~.x[, .(N = uniqueN(cluster)), by = dstype][, .(grp = .y, dstype, N)]) %>% 
    .[!is.na(dstype)] %>% 
    .[, .(dstype, N, P = N/sum(N)), by = grp]
# Out:
#    grp                                                 dstype N     P
# 1  Brain-Cerebellum_v_Cells-EBV-transformedlymphocytes AS-PR  16580 0.7683752
# 2  Brain-Cerebellum_v_Cells-EBV-transformedlymphocytes AS-NMD  4998 0.2316248
# 3  Brain-Cerebellum_v_Kidney-Cortex                    AS-PR  15586 0.7708972
# 4  Brain-Cerebellum_v_Kidney-Cortex                    AS-NMD  4632 0.2291028
# 5  Brain-Cerebellum_v_Liver                            AS-PR  15742 0.7689527
# 6  Brain-Cerebellum_v_Liver                            AS-NMD  4730 0.2310473
# 7  Liver_v_Kidney-Cortex                               AS-PR  10831 0.7901802
# 8  Liver_v_Kidney-Cortex                               AS-NMD  2876 0.2098198
# 9  Liver_v_Muscle-Skeletal                             AS-PR  15931 0.7847397
# 10 Liver_v_Muscle-Skeletal                             AS-NMD  4370 0.2152603

# %%
options(repr.plot.width = 4, repr.plot.height = 4, repr.plot.res = 180)

# %%
imap_dfr(betas.sig2, ~.x[, .(N = uniqueN(cluster)), by = dstype][, .(grp = .y, dstype, N)]) %>% 
    .[!is.na(dstype)] %>% 
    .[, .(dstype, N, P = N/sum(N)), by = grp]  %>% 
    ggplot() + geom_col(aes(x = grp, y = P, fill = dstype)) +
        geom_text(aes(x = grp, y = (1-P) + .1, label = N), size = 3) +
        scale_x_discrete(name = NULL, label = relabelLong) +
        scale_fill_brewer(name = NULL, palette = "Blues", direction = -1) +
        labs(y = NULL, title = relabelLong("DS clusters that lead to AS-NMD vs. AS PC isoforms", 30)) +
        theme(axis.text.x = element_text(angle = 90, vjust = .5),
              title = element_text(size = 10)
             )
# Out:
# plot without title

# %% [markdown]
# ## Distribution of AS-NMD vs. AS-PR introns

# %%
betas.sig2[[1]][, .N, by = .(dstype, itype)]
# Out:
#   dstype itype N
# 1 AS-PR  PR    57573
# 2 AS-PR  UP     6924
# 3 AS-NMD UP     7706
# 4 AS-NMD PR     5894

# %%
options(repr.plot.width = 15, repr.plot.height = 4, repr.plot.res = 180)

# %%
hist3 <- imap_dfr(betas.sig2, ~ .x[, .(intron, cluster, dstype, itype, ctype, deltapsi, grp=.y)]) %>%
    .[!is.na(dstype)] %>% 
    mutate(linecolor = paste(dstype, itype, sep=":")) %>% 
    ggplot() + stat_ecdf(aes(x = abs(deltapsi), color = linecolor)) +
        scale_x_continuous(trans = "sqrt", breaks = c(seq(0,.3, .1), .5, .75, 1)) +
        theme_bw() + 
        theme(legend.position = "bottom", legend.title = element_blank()) +
        facet_wrap(~grp, nrow = 1)

# %%
hist3
# Out:
# plot without title

# %% [markdown]
# **Interpretation:**
#
# 1. generally consistent trend with the previous plot where only differentiating introns from PR groups vs. introns from PR,UP groups
# 2. AS-NMD:PR and AS-PR both result in protein coding transcripts. These PR introns generally have larger abs(deltapsi)
# 3. UP introns generally have smaller delta psi.
# 4. Note howevefer, in AS-PR clusters, where there are both PR introns and UP introns, often larger delta PSI of PR introns are resulted from many UP introns with small deltaPSI (result of aggregation)

# %% [markdown]
# ## select top DS clusters and compare gene expressions
#
# - can split between UP and PR

# %%
th_adpsi = 0.2 # abs(deltapsi) threshold for selecting introns for plotting

# %%
# rank deltpsi
map(betas.sig2, ~.x[abs(deltapsi) > th_adpsi, .N, by= .(dstype, itype)][order(dstype, itype)])
# Out:
# $`Brain-Cerebellum_v_Cells-EBV-transformedlymphocytes`
#    dstype itype    N
# 1: AS-NMD    PR  558
# 2: AS-NMD    UP  565
# 3:  AS-PR    PR 4974
# 4:  AS-PR    UP  135
#
# $`Brain-Cerebellum_v_Kidney-Cortex`
#    dstype itype    N
# 1: AS-NMD    PR  457
# 2: AS-NMD    UP  473
# 3:  AS-PR    PR 4948
# 4:  AS-PR    UP  127
#
# $`Brain-Cerebellum_v_Liver`
#    dstype itype    N
# 1: AS-NMD    PR  548
# 2: AS-NMD    UP  555
# 3:  AS-PR    PR 5140
# 4:  AS-PR    UP  134
#
# $`Liver_v_Kidney-Cortex`
#    dstype itype   N
# 1: AS-NMD    PR  98
# 2: AS-NMD    UP 106
# 3:  AS-PR    PR 991
# 4:  AS-PR    UP  11
#
# $`Liver_v_Muscle-Skeletal`
#    dstype itype    N
# 1: AS-NMD    PR  381
# 2: AS-NMD    UP  346
# 3:  AS-PR    PR 3786
# 4:  AS-PR    UP   74

# %%
# select introns that pass min abs(deltapsi), used for subsequent plotting against expression

plot_introns <- imap_dfr(betas.sig2, ~.x[abs(deltapsi) > th_adpsi, .(cluster, intron, deltapsi, itype, ctype, nPR, dstype, grp = .y)])

# %%
head(plot_introns)
# Out:
#   cluster         intron                            deltapsi   itype ctype nPR
# 1 chr1:clu_1021_+ chr1:78080860:78092756:clu_1021_+ -0.9271973 UP    PR,UP  1
# 2 chr1:clu_1021_+ chr1:78080860:78094951:clu_1021_+  0.9271973 PR    PR,UP  1
# 3 chr1:clu_1026_+ chr1:78620571:78628950:clu_1026_+ -0.2703944 PR    PR     6
# 4 chr1:clu_104_+  chr1:5992788:6040516:clu_104_+    -0.7169977 PR    PR     5
# 5 chr1:clu_104_+  chr1:6026445:6040516:clu_104_+     0.7518235 PR    PR     5
# 6 chr1:clu_1040_+ chr1:84144548:84179176:clu_1040_+  0.9394977 PR    PR    11
#   dstype grp
# 1 AS-NMD Brain-Cerebellum_v_Cells-EBV-transformedlymphocytes
# 2 AS-NMD Brain-Cerebellum_v_Cells-EBV-transformedlymphocytes
# 3 AS-PR  Brain-Cerebellum_v_Cells-EBV-transformedlymphocytes
# 4 AS-PR  Brain-Cerebellum_v_Cells-EBV-transformedlymphocytes
# 5 AS-PR  Brain-Cerebellum_v_Cells-EBV-transformedlymphocytes
# 6 AS-PR  Brain-Cerebellum_v_Cells-EBV-transformedlymphocytes

# %%
plot_introns_to_bed <- str_split(plot_introns$intron, ":", simplify = T) %>% as.data.table
names(plot_introns_to_bed) <- c("seqname", "start", "end", "cluster")
plot_introns_to_bed[, `:=`(cluster = paste(seqname, cluster, sep=":"), strand = str_sub(cluster, -1, -1))]

# %%
plot_introns_to_bed <- makeGRangesFromDataFrame(plot_introns_to_bed, keep.extra.columns = T, ignore.strand = F, starts.in.df.are.0based = T)

# %%
olaps <- findOverlaps(plot_introns_to_bed, genes, minoverlap = 50, select = 'first')

# %%
mcols(plot_introns_to_bed) <- mcols(plot_introns_to_bed) %>%  # add gene info
    as_tibble %>% 
    cbind(mcols(genes[olaps]))

# %%
if (all(plot_introns_to_bed$cluster == plot_introns$cluster)) {
    print("do")
    plot_introns <- cbind(plot_introns, as.data.table(mcols(plot_introns_to_bed)[, c('gene_name', 'gene_id')]))
}
# Out:
# [1] "do"

# %% [markdown]
# Now, this table is ready to get leafcutter counts and tpm

# %%
plot_introns[1:5]
# Out:
#   cluster         intron                            deltapsi   itype ctype nPR
# 1 chr1:clu_1021_+ chr1:78080860:78092756:clu_1021_+ -0.9271973 UP    PR,UP 1
# 2 chr1:clu_1021_+ chr1:78080860:78094951:clu_1021_+  0.9271973 PR    PR,UP 1
# 3 chr1:clu_1026_+ chr1:78620571:78628950:clu_1026_+ -0.2703944 PR    PR    6
# 4 chr1:clu_104_+  chr1:5992788:6040516:clu_104_+    -0.7169977 PR    PR    5
# 5 chr1:clu_104_+  chr1:6026445:6040516:clu_104_+     0.7518235 PR    PR    5
#   dstype grp                                                 gene_name
# 1 AS-NMD Brain-Cerebellum_v_Cells-EBV-transformedlymphocytes GIPC2
# 2 AS-NMD Brain-Cerebellum_v_Cells-EBV-transformedlymphocytes GIPC2
# 3 AS-PR  Brain-Cerebellum_v_Cells-EBV-transformedlymphocytes IFI44L
# 4 AS-PR  Brain-Cerebellum_v_Cells-EBV-transformedlymphocytes KCNAB2
# 5 AS-PR  Brain-Cerebellum_v_Cells-EBV-transformedlymphocytes KCNAB2
#   gene_id
# 1 ENSG00000137960.6
# 2 ENSG00000137960.6
# 3 ENSG00000137959.17
# 4 ENSG00000069424.16
# 5 ENSG00000069424.16

# %%
tissues <- c("Brain-Cerebellum", "Cells-EBV-transformedlymphocytes",
            "Kidney-Cortex", "Liver", "Muscle-Skeletal")
tpm.f <- paste("../code/resources/GTEx/expression/", tissues, "_gene_tpm.tsv.gz", sep="")
names(tpm.f) <- tissues

# %%
tpm.f
# Out:
#                                                                     Brain-Cerebellum
#                 "../code/resources/GTEx/expression/Brain-Cerebellum_gene_tpm.tsv.gz"
#                                                     Cells-EBV-transformedlymphocytes
# "../code/resources/GTEx/expression/Cells-EBV-transformedlymphocytes_gene_tpm.tsv.gz"
#                                                                        Kidney-Cortex
#                    "../code/resources/GTEx/expression/Kidney-Cortex_gene_tpm.tsv.gz"
#                                                                                Liver
#                            "../code/resources/GTEx/expression/Liver_gene_tpm.tsv.gz"
#                                                                      Muscle-Skeletal
#                  "../code/resources/GTEx/expression/Muscle-Skeletal_gene_tpm.tsv.gz"

# %%
tpm <- map(tpm.f, fread)

# %%
# compute median tpm per gene
tpm <- map(tpm, ~.x[, .(Name, Description, medTPM = matrixStats::rowMedians(as.matrix(.SD))), .SDcols = names(.x)[-c(1:2)]])

# %%
names(tpm)
# Out:
# [1] "Brain-Cerebellum"                 "Cells-EBV-transformedlymphocytes"
# [3] "Kidney-Cortex"                    "Liver"
# [5] "Muscle-Skeletal"

# %%
tpm[[1]][1:2]
# Out:
#   Name              Description medTPM
# 1 ENSG00000223972.5 DDX11L1     0.000
# 2 ENSG00000227232.5 WASH7P      5.721

# %% [markdown]
# leafcutter numerators

# %%
getMedianLFcounts <- function(f) {
    # f: leafcutter count file for ds, eg.. results/ds/GTEx/Brain-Cerebellum_v_Cells-EBV-transformedlymphocytes/ds_perind_numers.counts.noise_by_intron.lf1.gz

    # leafcutter counts
    dt <- fread(f)
    
    header <- names(dt)

    # 2 group names
    groups <- header[-c(1)] %>% str_split('\\.') %>% map_chr(1) %>% unique

    # colnames for each group
    group1_cols <- header[str_detect(header, groups[1])]
    group2_cols <- header[str_detect(header, groups[2])]

    # new cole name for each group
    t1 <- groups[[1]]
    t2 <- groups[[2]]

    # compute row medians by group
    med1 <- dt[, ..group1_cols] %>% as.matrix %>% matrixStats::rowMedians(.)
    med2 <- dt[, ..group2_cols] %>% as.matrix %>% matrixStats::rowMedians(.)

    # output dt
    dt2 <- dt[, .(chrom)]
    dt2[, (t1) := med1]
    dt2[, (t2) := med2]

    return(dt2[])
}

# %%
counts.f <- paste("../code/results/ds/GTEx/", comps, "/ds_perind_numers.counts.noise_by_intron.gz", sep="")
names(counts.f)  <- comps

# %%
counts <- map(counts.f, getMedianLFcounts)

# %%
head(counts[[1]])
# Out:
#   chrom                         Brain-Cerebellum
# 1 chr1:779092:781936:clu_3_+:IN 0
# 2 chr1:779092:803918:clu_3_+:IN 0
# 3 chr1:804222:804775:clu_5_+:IN 1
# 4 chr1:804222:807216:clu_5_+:IN 0
# 5 chr1:804966:807216:clu_5_+:IN 0
# 6 chr1:807323:809657:clu_6_+:IN 0
#   Cells-EBV-transformedlymphocytes
# 1 0
# 2 0
# 3 1
# 4 0
# 5 0
# 6 0

# %%
head(plot_introns)
# Out:
#   cluster         intron                            deltapsi   itype ctype nPR
# 1 chr1:clu_1021_+ chr1:78080860:78092756:clu_1021_+ -0.9271973 UP    PR,UP  1
# 2 chr1:clu_1021_+ chr1:78080860:78094951:clu_1021_+  0.9271973 PR    PR,UP  1
# 3 chr1:clu_1026_+ chr1:78620571:78628950:clu_1026_+ -0.2703944 PR    PR     6
# 4 chr1:clu_104_+  chr1:5992788:6040516:clu_104_+    -0.7169977 PR    PR     5
# 5 chr1:clu_104_+  chr1:6026445:6040516:clu_104_+     0.7518235 PR    PR     5
# 6 chr1:clu_1040_+ chr1:84144548:84179176:clu_1040_+  0.9394977 PR    PR    11
#   dstype grp                                                 gene_name
# 1 AS-NMD Brain-Cerebellum_v_Cells-EBV-transformedlymphocytes GIPC2
# 2 AS-NMD Brain-Cerebellum_v_Cells-EBV-transformedlymphocytes GIPC2
# 3 AS-PR  Brain-Cerebellum_v_Cells-EBV-transformedlymphocytes IFI44L
# 4 AS-PR  Brain-Cerebellum_v_Cells-EBV-transformedlymphocytes KCNAB2
# 5 AS-PR  Brain-Cerebellum_v_Cells-EBV-transformedlymphocytes KCNAB2
# 6 AS-PR  Brain-Cerebellum_v_Cells-EBV-transformedlymphocytes PRKACB
#   gene_id
# 1 ENSG00000137960.6
# 2 ENSG00000137960.6
# 3 ENSG00000137959.17
# 4 ENSG00000069424.16
# 5 ENSG00000069424.16
# 6 ENSG00000142875.20

# %% [markdown]
# ## DS up deltapsi in Brain-Cerebellum_v_Cells-EBV-transformedlymphocytes

# %%
# gather data

dt_scatter1 <- plot_introns[grp == 'Brain-Cerebellum_v_Cells-EBV-transformedlymphocytes']

# %%
# BC vs. LCL on median tpm (L2FC)

l2fc1 <- inner_join(x = tpm[['Brain-Cerebellum']],
           y = tpm[['Cells-EBV-transformedlymphocytes']],
           by = c("Name", "Description"),
           suffix = c("_BC", "_LCL")
          ) %>% 
.[, .(Name, Description, medTPM_BC, medTPM_LCL, l2fc = log2(medTPM_LCL/medTPM_BC))] %>% 
.[!is.na(l2fc) & abs(l2fc) != Inf]

# %%
dt_scatter1[1:2]
# Out:
#   cluster         intron                            deltapsi   itype ctype nPR
# 1 chr1:clu_1021_+ chr1:78080860:78092756:clu_1021_+ -0.9271973 UP    PR,UP 1
# 2 chr1:clu_1021_+ chr1:78080860:78094951:clu_1021_+  0.9271973 PR    PR,UP 1
#   dstype grp                                                 gene_name
# 1 AS-NMD Brain-Cerebellum_v_Cells-EBV-transformedlymphocytes GIPC2
# 2 AS-NMD Brain-Cerebellum_v_Cells-EBV-transformedlymphocytes GIPC2
#   gene_id
# 1 ENSG00000137960.6
# 2 ENSG00000137960.6

# %%
l2fc1[1:2]
# Out:
#   Name              Description medTPM_BC medTPM_LCL l2fc
# 1 ENSG00000227232.5 WASH7P      5.72100   2.494500   -1.1975167
# 2 ENSG00000186092.4 OR4F5       0.05772   0.030985   -0.8975013

# %%
dt_scatter1 <- left_join(x = dt_scatter1, 
                         y = l2fc1[, .(gene_name = Description, l2fc)],
                         by = 'gene_name') %>% 
    .[!is.na(l2fc) & abs(l2fc) > 1 & abs(l2fc) != Inf]
# Out:
# Warning message in left_join(x = dt_scatter1, y = l2fc1[, .(gene_name = Description, :
# “Detected an unexpected many-to-many relationship between `x` and `y`.
# ℹ Row 444 of `x` matches multiple rows in `y`.
# ℹ Row 1045 of `y` matches multiple rows in `x`.
# ℹ If a many-to-many relationship is expected, set `relationship =
#   "many-to-many"` to silence this warning.”

# %%
dt_scatter1[1:5]
# Out:
#   cluster         intron                            deltapsi   itype ctype nPR
# 1 chr1:clu_1021_+ chr1:78080860:78092756:clu_1021_+ -0.9271973 UP    PR,UP  1
# 2 chr1:clu_1021_+ chr1:78080860:78094951:clu_1021_+  0.9271973 PR    PR,UP  1
# 3 chr1:clu_1026_+ chr1:78620571:78628950:clu_1026_+ -0.2703944 PR    PR     6
# 4 chr1:clu_1040_+ chr1:84144548:84179176:clu_1040_+  0.9394977 PR    PR    11
# 5 chr1:clu_1040_+ chr1:84173352:84175032:clu_1040_+ -0.2345420 PR    PR    11
#   dstype grp                                                 gene_name
# 1 AS-NMD Brain-Cerebellum_v_Cells-EBV-transformedlymphocytes GIPC2
# 2 AS-NMD Brain-Cerebellum_v_Cells-EBV-transformedlymphocytes GIPC2
# 3 AS-PR  Brain-Cerebellum_v_Cells-EBV-transformedlymphocytes IFI44L
# 4 AS-PR  Brain-Cerebellum_v_Cells-EBV-transformedlymphocytes PRKACB
# 5 AS-PR  Brain-Cerebellum_v_Cells-EBV-transformedlymphocytes PRKACB
#   gene_id            l2fc
# 1 ENSG00000137960.6  -2.197214
# 2 ENSG00000137960.6  -2.197214
# 3 ENSG00000137959.17  6.440915
# 4 ENSG00000142875.20 -3.485495
# 5 ENSG00000142875.20 -3.485495

# %%
dt_scatter1 %>% dim
# Out:
# [1] 3704   11

# %%
cortest1 <- dt_scatter1[, .(deltapsi, l2fc, itype)] %>% 
    split(by = c("itype")) %>% 
    map(~.x %$% cor.test(l2fc, deltapsi, method = 'p'))

# %%
cortest1.df <- data.table(itype = names(cortest1),
           pval = map_dbl(cortest1, ~.x[['p.value']]),
           cor = map_dbl(cortest1, ~.x[['estimate']])
          ) %>% 
    add_column(label = glue::glue("corr: {scales::number(.$cor, .001)}, p: {scales::scientific(.$pval, 2)}"))

# %%
cortest1 %>% print
cortest1.df
# Out:
# $UP
#
# 	Pearson's product-moment correlation
#
# data:  l2fc and deltapsi
# t = -6.809, df = 418, p-value = 3.43e-11
# alternative hypothesis: true correlation is not equal to 0
# 95 percent confidence interval:
#  -0.3995805 -0.2271572
# sample estimates:
#        cor
# -0.3159754
#
#
# $PR
#
# 	Pearson's product-moment correlation
#
# data:  l2fc and deltapsi
# t = 1.9595, df = 3282, p-value = 0.05014
# alternative hypothesis: true correlation is not equal to 0
# 95 percent confidence interval:
#  -0.0000204615  0.0683074812
# sample estimates:
#        cor
# 0.03418345
#   itype pval         cor         label
# 1 UP    3.430370e-11 -0.31597541 corr: -0.316, p: 3.4e-11
# 2 PR    5.014203e-02  0.03418345 corr: 0.034, p: 5.0e-02

# %%
options(repr.plot.width = 6, repr.plot.height = 4, repr.plot.res = 180)

# %%
dt_scatter1 %>% 
    ggplot() + geom_point(aes(l2fc, deltapsi), alpha = .3, color = 'grey20', size = .1) +
        geom_smooth(aes(l2fc, deltapsi), method = "lm", formula = 'y~x', se = F, linetype = 'dashed', size =.5, color = 'firebrick') +
        geom_text(aes(x = 0, y = .1, label = label), data = cortest1.df, color = 'firebrick', size = 4) + 
        scale_x_continuous(limits = c(-10, 10), breaks = seq(-10,10,2)) +
        labs(x = 'Log2 FC of median TPM - LCL / Brain Cerebellum') +
        facet_wrap(~itype, nrow=1)
# Out:
# Warning message:
# “Removed 40 rows containing non-finite values (`stat_smooth()`).”
# Warning message:
# “Removed 40 rows containing missing values (`geom_point()`).”
# plot without title

# %% [markdown]
# ## DS up deltapsi in Liver_v_Muscle-Skeletal

# %%
# gather data

dt_scatter2 <- plot_introns[grp == 'Liver_v_Muscle-Skeletal']

# %%
# BC vs. LCL on median tpm (L2FC)

l2fc2 <- inner_join(x = tpm[['Liver']],
           y = tpm[['Muscle-Skeletal']],
           by = c("Name", "Description"),
           suffix = c("_Liver", "_Muscle")
          ) %>% 
.[, .(Name, Description, medTPM_Liver, medTPM_Muscle, l2fc = log2(medTPM_Muscle/medTPM_Liver))] %>% 
.[!is.na(l2fc) & abs(l2fc) != Inf]

# %%
dt_scatter2[1:2]
# Out:
#   cluster         intron                            deltapsi   itype ctype nPR
# 1 chr1:clu_1018_+ chr1:77916133:77917565:clu_1018_+  0.2778550 PR    PR    3
# 2 chr1:clu_1018_+ chr1:77916133:77917959:clu_1018_+ -0.5767754 PR    PR    3
#   dstype grp                     gene_name gene_id
# 1 AS-PR  Liver_v_Muscle-Skeletal NEXN      ENSG00000162614.19
# 2 AS-PR  Liver_v_Muscle-Skeletal NEXN      ENSG00000162614.19

# %%
l2fc2[1:2]
# Out:
#   Name              Description medTPM_Liver medTPM_Muscle l2fc
# 1 ENSG00000227232.5 WASH7P      1.76550      1.41700       -0.3172371
# 2 ENSG00000268020.3 OR4G4P      0.03327      0.03752        0.1734380

# %%
dt_scatter2 <- left_join(x = dt_scatter2, 
                         y = l2fc2[, .(gene_name = Description, l2fc)],
                         by = 'gene_name') %>% 
    .[!is.na(l2fc) & abs(l2fc) > 1 & abs(l2fc) != Inf]
# Out:
# Warning message in left_join(x = dt_scatter2, y = l2fc2[, .(gene_name = Description, :
# “Detected an unexpected many-to-many relationship between `x` and `y`.
# ℹ Row 374 of `x` matches multiple rows in `y`.
# ℹ Row 1003 of `y` matches multiple rows in `x`.
# ℹ If a many-to-many relationship is expected, set `relationship =
#   "many-to-many"` to silence this warning.”

# %%
dt_scatter2[1:5]
# Out:
#   cluster         intron                            deltapsi   itype ctype nPR
# 1 chr1:clu_1018_+ chr1:77916133:77917565:clu_1018_+  0.2778550 PR    PR    3
# 2 chr1:clu_1018_+ chr1:77916133:77917959:clu_1018_+ -0.5767754 PR    PR    3
# 3 chr1:clu_1018_+ chr1:77917757:77917959:clu_1018_+  0.2989204 PR    PR    3
# 4 chr1:clu_1019_+ chr1:77918273:77926413:clu_1019_+  0.3278041 PR    PR    3
# 5 chr1:clu_1021_+ chr1:78080860:78092756:clu_1021_+  0.6063410 UP    PR,UP 1
#   dstype grp                     gene_name gene_id            l2fc
# 1 AS-PR  Liver_v_Muscle-Skeletal NEXN      ENSG00000162614.19  7.251513
# 2 AS-PR  Liver_v_Muscle-Skeletal NEXN      ENSG00000162614.19  7.251513
# 3 AS-PR  Liver_v_Muscle-Skeletal NEXN      ENSG00000162614.19  7.251513
# 4 AS-PR  Liver_v_Muscle-Skeletal NEXN      ENSG00000162614.19  7.251513
# 5 AS-NMD Liver_v_Muscle-Skeletal GIPC2     ENSG00000137960.6  -3.325675

# %%
dim(dt_scatter2)
# Out:
# [1] 2515   11

# %%
cortest2 <- dt_scatter2[, .(deltapsi, l2fc, itype)] %>% 
    split(by = c("itype")) %>% 
    map(~.x %$% cor.test(l2fc, deltapsi, method = 'p'))

# %%
cortest2.df <- data.table(itype = names(cortest2),
           pval = map_dbl(cortest2, ~.x[['p.value']]),
           cor = map_dbl(cortest2, ~.x[['estimate']])
          ) %>% 
    add_column(label = glue::glue("corr: {scales::number(.$cor, .001)}, p: {scales::scientific(.$pval, 2)}"))

# %%
cortest2 %>% print
cortest2.df
# Out:
# $PR
#
# 	Pearson's product-moment correlation
#
# data:  l2fc and deltapsi
# t = 0.68924, df = 3944, p-value = 0.4907
# alternative hypothesis: true correlation is not equal to 0
# 95 percent confidence interval:
#  -0.02023549  0.04216262
# sample estimates:
#        cor
# 0.01097424
#
#
# $UP
#
# 	Pearson's product-moment correlation
#
# data:  l2fc and deltapsi
# t = -2.8475, df = 387, p-value = 0.004641
# alternative hypothesis: true correlation is not equal to 0
# 95 percent confidence interval:
#  -0.23927639 -0.04445801
# sample estimates:
#        cor
# -0.1432547
#   itype pval       cor         label
# 1 PR    0.49071405  0.01097424 corr: 0.011, p: 4.9e-01
# 2 UP    0.00464105 -0.14325468 corr: -0.143, p: 4.6e-03

# %%
options(repr.plot.width = 6, repr.plot.height = 4, repr.plot.res = 180)

# %%
dt_scatter2 %>% 
    ggplot() + geom_point(aes(l2fc, deltapsi), alpha = .3, color = 'grey20', size = .1) +
        geom_smooth(aes(l2fc, deltapsi), method = "lm", formula = 'y~x', se = F, linetype = 'dashed', size =.5, color = 'firebrick') +
        geom_text(aes(x = 0, y = .1, label = label), data = cortest2.df, color = 'firebrick', size = 4) + 
        scale_x_continuous(limits = c(-10, 10), breaks = seq(-10,10,2)) +
        labs(x = 'Log2 FC of median TPM - Muscle-Skeletal / Liver') +
        facet_wrap(~itype, nrow=1)
# Out:
# Warning message:
# “Removed 24 rows containing non-finite values (`stat_smooth()`).”
# Warning message:
# “Removed 24 rows containing missing values (`geom_point()`).”
# plot without title

# %% [markdown]
# # Look for regions to plot sashimi

# %%
plot_introns[grp == 'Brain-Cerebellum_v_Cells-EBV-transformedlymphocytes'] %>% 
    .[dstype == 'AS-NMD' & ]
# Out:
#      cluster          intron                               deltapsi   itype
# 1    chr1:clu_1021_+  chr1:78080860:78092756:clu_1021_+    -0.9271973 UP
# 2    chr1:clu_1021_+  chr1:78080860:78094951:clu_1021_+     0.9271973 PR
# 3    chr1:clu_1118_+  chr1:96804939:96806418:clu_1118_+    -0.2954049 PR
# 4    chr1:clu_1118_+  chr1:96804939:96806865:clu_1118_+     0.7584031 UP
# 5    chr1:clu_1118_+  chr1:96806452:96806865:clu_1118_+    -0.4629982 PR
# 6    chr1:clu_1175_+  chr1:109200900:109202912:clu_1175_+  -0.2474657 UP
# 7    chr1:clu_1175_+  chr1:109200900:109202943:clu_1175_+   0.2474657 PR
# 8    chr1:clu_1179_+  chr1:109484080:109486056:clu_1179_+   0.4548809 PR
# 9    chr1:clu_1179_+  chr1:109485509:109486056:clu_1179_+  -0.3800595 UP
# 10   chr1:clu_1190_+  chr1:109657279:109657771:clu_1190_+  -0.2288644 UP
# 11   chr1:clu_1220_+  chr1:111161296:111174878:clu_1220_+   0.3876674 PR
# 12   chr1:clu_1220_+  chr1:111173258:111174878:clu_1220_+  -0.3876674 UP
# 13   chr1:clu_1234_+  chr1:111477078:111477982:clu_1234_+  -0.5712515 UP
# 14   chr1:clu_1234_+  chr1:111477775:111477982:clu_1234_+   0.5712515 PR
# 15   chr1:clu_1256_+  chr1:113100488:113107593:clu_1256_+  -0.4361619 PR
# 16   chr1:clu_1319_+  chr1:145623160:145623592:clu_1319_+  -0.3994062 UP
# 17   chr1:clu_1319_+  chr1:145623160:145623612:clu_1319_+   0.3994062 PR
# 18   chr1:clu_1322_+  chr1:145644067:145647174:clu_1322_+  -0.2821138 UP
# 19   chr1:clu_1322_+  chr1:145646272:145647174:clu_1322_+   0.2821138 PR
# 20   chr1:clu_1349_+  chr1:147541674:147604776:clu_1349_+  -0.6067458 PR
# 21   chr1:clu_1349_+  chr1:147600337:147604776:clu_1349_+   0.6067458 UP
# 22   chr1:clu_1352_+  chr1:147943544:147943976:clu_1352_+  -0.2790308 UP
# 23   chr1:clu_1352_+  chr1:147943544:147943996:clu_1352_+   0.2790308 PR
# 24   chr1:clu_1361_+  chr1:148863305:148868470:clu_1361_+   0.6504178 PR
# 25   chr1:clu_1361_+  chr1:148866532:148868470:clu_1361_+  -0.2085489 UP
# 26   chr1:clu_1408_+  chr1:150344261:150344375:clu_1408_+  -0.2961648 UP
# 27   chr1:clu_1408_+  chr1:150344261:150344433:clu_1408_+   0.2961648 PR
# 28   chr1:clu_1490_+  chr1:154337544:154340536:clu_1490_+  -0.2287451 UP
# 29   chr1:clu_1490_+  chr1:154337544:154340853:clu_1490_+   0.4669602 PR
# 30   chr1:clu_1490_+  chr1:154340543:154340853:clu_1490_+  -0.2382151 UP
# ⋮    ⋮                ⋮                                    ⋮          ⋮
# 1094 chrX:clu_46735_+ chrX:48575667:48576313:clu_46735_+    0.2515101 PR
# 1095 chrX:clu_46793_+ chrX:53094284:53094399:clu_46793_+   -0.2250988 UP
# 1096 chrX:clu_46815_+ chrX:57448718:57452130:clu_46815_+    0.3118600 UP
# 1097 chrX:clu_46815_+ chrX:57448718:57488756:clu_46815_+   -0.3118600 PR
# 1098 chrX:clu_46858_+ chrX:71424238:71454169:clu_46858_+    0.3695569 PR
# 1099 chrX:clu_46926_+ chrX:101446044:101447493:clu_46926_+  0.4357627 UP
# 1100 chrX:clu_46926_+ chrX:101485530:101486022:clu_46926_+ -0.3603961 PR
# 1101 chrX:clu_46964_+ chrX:103919292:103931015:clu_46964_+  0.2810728 UP
# 1102 chrX:clu_46964_+ chrX:103919292:103962020:clu_46964_+ -0.2810728 PR
# 1103 chrX:clu_47091_+ chrX:135577295:135579787:clu_47091_+ -0.2232896 UP
# 1104 chrX:clu_47091_+ chrX:135577427:135579787:clu_47091_+  0.2232896 PR
# 1105 chrX:clu_47326_- chrX:18897333:18899172:clu_47326_-    0.2566388 PR
# 1106 chrX:clu_47326_- chrX:18897333:18901484:clu_47326_-   -0.5426006 UP
# 1107 chrX:clu_47326_- chrX:18900699:18901484:clu_47326_-    0.2859618 PR
# 1108 chrX:clu_47340_- chrX:19917334:19918071:clu_47340_-   -0.2525222 UP
# 1109 chrX:clu_47340_- chrX:19917334:19929784:clu_47340_-    0.3620055 PR
# 1110 chrX:clu_47343_- chrX:20016325:20024950:clu_47343_-   -0.5080446 PR
# 1111 chrX:clu_47343_- chrX:20021549:20024950:clu_47343_-    0.5080446 UP
# 1112 chrX:clu_47412_- chrX:47628277:47628475:clu_47412_-   -0.4080736 UP
# 1113 chrX:clu_47412_- chrX:47628277:47629523:clu_47412_-    0.8082623 PR
# 1114 chrX:clu_47412_- chrX:47628553:47629523:clu_47412_-   -0.4001886 UP
# 1115 chrX:clu_47509_- chrX:56984478:56994722:clu_47509_-   -0.3251163 UP
# 1116 chrX:clu_47509_- chrX:56993888:56994722:clu_47509_-    0.2713597 UP
# 1117 chrX:clu_47526_- chrX:65525050:65529211:clu_47526_-   -0.2031355 UP
# 1118 chrX:clu_47585_- chrX:77593849:77599410:clu_47585_-   -0.2133919 PR
# 1119 chrX:clu_47626_- chrX:101895882:101897867:clu_47626_-  0.2321147 UP
# 1120 chrX:clu_47881_- chrX:155299145:155309571:clu_47881_- -0.3892776 UP
# 1121 chrX:clu_47881_- chrX:155299145:155334370:clu_47881_-  0.3892776 PR
# 1122 chrY:clu_47945_- chrY:19716004:19716278:clu_47945_-    0.2779045 PR
# 1123 chrY:clu_47945_- chrY:19716111:19716278:clu_47945_-   -0.2779045 UP
#      ctype nPR dstype grp
# 1    PR,UP 1   AS-NMD Brain-Cerebellum_v_Cells-EBV-transformedlymphocytes
# 2    PR,UP 1   AS-NMD Brain-Cerebellum_v_Cells-EBV-transformedlymphocytes
# 3    PR,UP 2   AS-NMD Brain-Cerebellum_v_Cells-EBV-transformedlymphocytes
# 4    PR,UP 2   AS-NMD Brain-Cerebellum_v_Cells-EBV-transformedlymphocytes
# 5    PR,UP 2   AS-NMD Brain-Cerebellum_v_Cells-EBV-transformedlymphocytes
# 6    PR,UP 1   AS-NMD Brain-Cerebellum_v_Cells-EBV-transformedlymphocytes
# 7    PR,UP 1   AS-NMD Brain-Cerebellum_v_Cells-EBV-transformedlymphocytes
# 8    PR,UP 1   AS-NMD Brain-Cerebellum_v_Cells-EBV-transformedlymphocytes
# 9    PR,UP 1   AS-NMD Brain-Cerebellum_v_Cells-EBV-transformedlymphocytes
# 10   PR,UP 2   AS-NMD Brain-Cerebellum_v_Cells-EBV-transformedlymphocytes
# 11   PR,UP 1   AS-NMD Brain-Cerebellum_v_Cells-EBV-transformedlymphocytes
# 12   PR,UP 1   AS-NMD Brain-Cerebellum_v_Cells-EBV-transformedlymphocytes
# 13   PR,UP 1   AS-NMD Brain-Cerebellum_v_Cells-EBV-transformedlymphocytes
# 14   PR,UP 1   AS-NMD Brain-Cerebellum_v_Cells-EBV-transformedlymphocytes
# 15   PR,UP 1   AS-NMD Brain-Cerebellum_v_Cells-EBV-transformedlymphocytes
# 16   PR,UP 1   AS-NMD Brain-Cerebellum_v_Cells-EBV-transformedlymphocytes
# 17   PR,UP 1   AS-NMD Brain-Cerebellum_v_Cells-EBV-transformedlymphocytes
# 18   PR,UP 1   AS-NMD Brain-Cerebellum_v_Cells-EBV-transformedlymphocytes
# 19   PR,UP 1   AS-NMD Brain-Cerebellum_v_Cells-EBV-transformedlymphocytes
# 20   PR,UP 1   AS-NMD Brain-Cerebellum_v_Cells-EBV-transformedlymphocytes
# 21   PR,UP 1   AS-NMD Brain-Cerebellum_v_Cells-EBV-transformedlymphocytes
# 22   PR,UP 1   AS-NMD Brain-Cerebellum_v_Cells-EBV-transformedlymphocytes
# 23   PR,UP 1   AS-NMD Brain-Cerebellum_v_Cells-EBV-transformedlymphocytes
# 24   PR,UP 1   AS-NMD Brain-Cerebellum_v_Cells-EBV-transformedlymphocytes
# 25   PR,UP 1   AS-NMD Brain-Cerebellum_v_Cells-EBV-transformedlymphocytes
# 26   PR,UP 1   AS-NMD Brain-Cerebellum_v_Cells-EBV-transformedlymphocytes
# 27   PR,UP 1   AS-NMD Brain-Cerebellum_v_Cells-EBV-transformedlymphocytes
# 28   PR,UP 1   AS-NMD Brain-Cerebellum_v_Cells-EBV-transformedlymphocytes
# 29   PR,UP 1   AS-NMD Brain-Cerebellum_v_Cells-EBV-transformedlymphocytes
# 30   PR,UP 1   AS-NMD Brain-Cerebellum_v_Cells-EBV-transformedlymphocytes
# ⋮    ⋮     ⋮   ⋮      ⋮
# 1094 PR,UP 2   AS-NMD Brain-Cerebellum_v_Cells-EBV-transformedlymphocytes
# 1095 PR,UP 2   AS-NMD Brain-Cerebellum_v_Cells-EBV-transformedlymphocytes
# 1096 PR,UP 1   AS-NMD Brain-Cerebellum_v_Cells-EBV-transformedlymphocytes
# 1097 PR,UP 1   AS-NMD Brain-Cerebellum_v_Cells-EBV-transformedlymphocytes
# 1098 PR,UP 1   AS-NMD Brain-Cerebellum_v_Cells-EBV-transformedlymphocytes
# 1099 PR,UP 3   AS-NMD Brain-Cerebellum_v_Cells-EBV-transformedlymphocytes
# 1100 PR,UP 3   AS-NMD Brain-Cerebellum_v_Cells-EBV-transformedlymphocytes
# 1101 PR,UP 1   AS-NMD Brain-Cerebellum_v_Cells-EBV-transformedlymphocytes
# 1102 PR,UP 1   AS-NMD Brain-Cerebellum_v_Cells-EBV-transformedlymphocytes
# 1103 PR,UP 1   AS-NMD Brain-Cerebellum_v_Cells-EBV-transformedlymphocytes
# 1104 PR,UP 1   AS-NMD Brain-Cerebellum_v_Cells-EBV-transformedlymphocytes
# 1105 PR,UP 2   AS-NMD Brain-Cerebellum_v_Cells-EBV-transformedlymphocytes
# 1106 PR,UP 2   AS-NMD Brain-Cerebellum_v_Cells-EBV-transformedlymphocytes
# 1107 PR,UP 2   AS-NMD Brain-Cerebellum_v_Cells-EBV-transformedlymphocytes
# 1108 PR,UP 1   AS-NMD Brain-Cerebellum_v_Cells-EBV-transformedlymphocytes
# 1109 PR,UP 1   AS-NMD Brain-Cerebellum_v_Cells-EBV-transformedlymphocytes
# 1110 PR,UP 1   AS-NMD Brain-Cerebellum_v_Cells-EBV-transformedlymphocytes
# 1111 PR,UP 1   AS-NMD Brain-Cerebellum_v_Cells-EBV-transformedlymphocytes
# 1112 PR,UP 1   AS-NMD Brain-Cerebellum_v_Cells-EBV-transformedlymphocytes
# 1113 PR,UP 1   AS-NMD Brain-Cerebellum_v_Cells-EBV-transformedlymphocytes
# 1114 PR,UP 1   AS-NMD Brain-Cerebellum_v_Cells-EBV-transformedlymphocytes
# 1115 PR,UP 1   AS-NMD Brain-Cerebellum_v_Cells-EBV-transformedlymphocytes
# 1116 PR,UP 1   AS-NMD Brain-Cerebellum_v_Cells-EBV-transformedlymphocytes
# 1117 PR,UP 2   AS-NMD Brain-Cerebellum_v_Cells-EBV-transformedlymphocytes
# 1118 PR,UP 1   AS-NMD Brain-Cerebellum_v_Cells-EBV-transformedlymphocytes
# 1119 PR,UP 1   AS-NMD Brain-Cerebellum_v_Cells-EBV-transformedlymphocytes
# 1120 PR,UP 1   AS-NMD Brain-Cerebellum_v_Cells-EBV-transformedlymphocytes
# 1121 PR,UP 1   AS-NMD Brain-Cerebellum_v_Cells-EBV-transformedlymphocytes
# 1122 PR,UP 1   AS-NMD Brain-Cerebellum_v_Cells-EBV-transformedlymphocytes
# 1123 PR,UP 1   AS-NMD Brain-Cerebellum_v_Cells-EBV-transformedlymphocytes
#      gene_name gene_id
# 1    GIPC2     ENSG00000137960.6
# 2    GIPC2     ENSG00000137960.6
# 3    PTBP2     ENSG00000117569.20
# 4    PTBP2     ENSG00000117569.20
# 5    PTBP2     ENSG00000117569.20
# 6    ELAPOR1   ENSG00000116299.17
# 7    ELAPOR1   ENSG00000116299.17
# 8    ATXN7L2   ENSG00000162650.17
# 9    ATXN7L2   ENSG00000162650.17
# 10   GSTM4     ENSG00000168765.19
# 11   CEPT1     ENSG00000134255.16
# 12   CEPT1     ENSG00000134255.16
# 13   C1orf162  ENSG00000143110.12
# 14   C1orf162  ENSG00000143110.12
# 15   LRIG2     ENSG00000198799.12
# 16   GPR89A    ENSG00000117262.19
# 17   GPR89A    ENSG00000117262.19
# 18   GPR89A    ENSG00000117262.19
# 19   GPR89A    ENSG00000117262.19
# 20   BCL9      ENSG00000116128.12
# 21   BCL9      ENSG00000116128.12
# 22   GPR89B    ENSG00000188092.15
# 23   GPR89B    ENSG00000188092.15
# 24   PDE4DIP   ENSG00000178104.22
# 25   PDE4DIP   ENSG00000178104.22
# 26   PRPF3     ENSG00000117360.13
# 27   PRPF3     ENSG00000117360.13
# 28   ATP8B2    ENSG00000143515.20
# 29   ATP8B2    ENSG00000143515.20
# 30   ATP8B2    ENSG00000143515.20
# ⋮    ⋮         ⋮
# 1094 RBM3      ENSG00000102317.18
# 1095 KANTR     ENSG00000232593.8
# 1096 FAAH2     ENSG00000165591.7
# 1097 FAAH2     ENSG00000165591.7
# 1098 TAF1      ENSG00000147133.17
# 1099 ARMCX4    ENSG00000196440.12
# 1100 ARMCX4    ENSG00000196440.12
# 1101 TMSB15B   ENSG00000158427.15
# 1102 TMSB15B   ENSG00000158427.15
# 1103 INTS6L    ENSG00000165359.16
# 1104 INTS6L    ENSG00000165359.16
# 1105 PHKA2     ENSG00000044446.12
# 1106 PHKA2     ENSG00000044446.12
# 1107 PHKA2     ENSG00000044446.12
# 1108 BCLAF3    ENSG00000173681.17
# 1109 BCLAF3    ENSG00000173681.17
# 1110 MAP7D2    ENSG00000184368.16
# 1111 MAP7D2    ENSG00000184368.16
# 1112 CFP       ENSG00000126759.14
# 1113 CFP       ENSG00000126759.14
# 1114 CFP       ENSG00000126759.14
# 1115 SPIN3     ENSG00000204271.13
# 1116 SPIN3     ENSG00000204271.13
# 1117 LAS1L     ENSG00000001497.18
# 1118 ATRX      ENSG00000085224.23
# 1119 ZMAT1     ENSG00000166432.16
# 1120 CLIC2     ENSG00000155962.13
# 1121 CLIC2     ENSG00000155962.13
# 1122 KDM5D     ENSG00000012817.16
# 1123 KDM5D     ENSG00000012817.16

# %%
pryr::mem_used()
# Out:
# 851 MB

# %%
ls()
# Out:
#  [1] "betas"               "betas.f"             "betas.sig"
#  [4] "betas.sig2"          "brain1"              "cn"
#  [7] "col2"                "comps"               "counts"
# [10] "counts.f"            "ds_clusters"         "ds_tbd"
# [13] "dt"                  "dt_scatter1"         "dt_scatter2"
# [16] "dt_scatter3"         "dt_scatter4"         "dt2"
# [19] "FDR"                 "genes"               "getIntronLabels"
# [22] "getMedianLFcounts"   "group1_cols"         "group2_cols"
# [25] "groups"              "header"              "hist1"
# [28] "hist2"               "hist2.2"             "hist3"
# [31] "introns"             "introns.f"           "labelClusterDStype"
# [34] "lcl1"                "liver1"              "med1"
# [37] "med2"                "muscle1"             "muslce1"
# [40] "newcols"             "olaps"               "plot_introns"
# [43] "plot_introns_to_bed" "pvals"               "pvals.f"
# [46] "relabelLong"         "sig.clusters"        "t1"
# [49] "t2"                  "th_adpsi"            "tissues"
# [52] "tpm"                 "tpm.f"               "v1"
# [55] "v2"                  "x"                   "xx"
